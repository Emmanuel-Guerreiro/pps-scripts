# %%
# Data Harmonizer - Pydantic Models and Configuration Loading
# This notebook demonstrates how to load and work with data harmonization configurations

from pydantic import BaseModel
from typing import List
import yaml

# %%
class FieldMapping(BaseModel):
    """Represents a single field mapping between source and target."""
    source_field: str
    target_field: str


class DataMapping(BaseModel):
    """Represents a complete data mapping configuration."""
    origin: str
    fields_map: List[FieldMapping]

# %%
def load_config_mappings(config_path: str) -> dict:
    """
    Load configuration from YAML file and convert to dict with target_classes, target_dataset_path and datasets.
    
    Args:
        config_path: Path to the YAML configuration file
        
    Returns:
        Dict with target_classes, target_dataset_path and datasets fields
    """
    with open(config_path, 'r') as file:
        config_data = yaml.safe_load(file)
    
    # Convert datasets to Pydantic objects
    datasets = []
    for mapping_config in config_data["datasets"]:
        # Convert each mapping to Pydantic objects
        field_mappings = [
            FieldMapping(
                source_field=field["source_field"],
                target_field=field["target_field"]
            )
            for field in mapping_config["fields_map"]
        ]
        
        data_mapping = DataMapping(
            origin=mapping_config["origin"],
            fields_map=field_mappings
        )
        datasets.append(data_mapping)
    
    return {
        "target_classes": config_data["target_classes"],
        "target_dataset_path": config_data["target_dataset_path"],
        "datasets": datasets
    }

# %%
import os
def generate_internal_structure(config, step_path):
    if not os.path.exists(config["target_dataset_path"] + f"/{step_path}" + "/images"):
        os.makedirs(config["target_dataset_path"] + f"/{step_path}" + "/images")
    if not os.path.exists(config["target_dataset_path"] + f"/{step_path}" + "/labels"):
        os.makedirs(config["target_dataset_path"] + f"/{step_path}" + "/labels")

def generate_target_dataset_path(config):
    if not os.path.exists(config["target_dataset_path"]):
        os.makedirs(config["target_dataset_path"])
    generate_internal_structure(config, "train")
    generate_internal_structure(config, "valid")
    generate_internal_structure(config, "test")
    
    return config["target_dataset_path"]

# %%
def generate_target_yolo_data_file(config):
    import yaml
    import os
    
    data_yaml_path = os.path.join(config["target_dataset_path"], "data.yaml")
    names = f"[{', '.join(config['target_classes'])}]"
    print(names)
    # Create the YOLO data structure
    yolo_data = {
        'train': '../train/images',
        'val': '../valid/images', 
        'test': '../test/images',
        'nc': len(config['target_classes']),
        'names': names
    }
    
    if not os.path.exists(data_yaml_path):
        with open(data_yaml_path, "w") as file:
            yaml.dump(yolo_data, file)
    
    return data_yaml_path

# %%
from typing import Dict

def extract_origin_classes(dataset: DataMapping):
    with open(dataset.origin + "/data.yaml", 'r') as file:
        classes = yaml.safe_load(file)
    return classes["names"]

def map_classes(config_classes: List[FieldMapping], target_classes: List[str], origin_classes_list: List[str]) -> Dict[int, int]:
    """
     THe result is a dict {idx_origin_class: idx_target_class}
     The idea is that this mapping will be used to map the classes of the origin dataset to the target dataset
    """
    origin_classes_indexed = {origin_classes_list[i]: i for i in range(len(origin_classes_list))}
    target_classes_indexed = {target_classes[i]: i for i in range(len(target_classes))}

    
    result = {}
    for config_class in config_classes:
        result[origin_classes_indexed[config_class.source_field]] = target_classes_indexed[config_class.target_field]
    return result

def copy_images(origin_path: str, target_dataset_path: str):
    import os
    import shutil
    
    # Define source and target image directories
    source_images_dir = os.path.join(origin_path, "images")
    target_images_dir = os.path.join(target_dataset_path, "images")
    
    # Check if source images directory exists
    if not os.path.exists(source_images_dir):
        print(f"❌ Source images directory not found: {source_images_dir}")
        return False
    
    # Create target images directory if it doesn't exist
    os.makedirs(target_images_dir, exist_ok=True)
    
    # Copy all files from source to target
    try:
        for filename in os.listdir(source_images_dir):
            source_file = os.path.join(source_images_dir, filename)
            target_file = os.path.join(target_images_dir, filename)
            
            # Only copy files (not directories)
            if os.path.isfile(source_file):
                shutil.copy2(source_file, target_file)
                print(f"✅ Copied: {filename}")
        
        print(f"✅ Successfully copied all images from {source_images_dir} to {target_images_dir}")
        return True
        
    except Exception as e:
        print(f"❌ Error copying images: {str(e)}")
        return False

def transform_and_copy_labels(origin_path: str, target_dataset_path: str, classes: Dict[int, int]):
    """
    Transform and copy label files from origin to target dataset.
    
    Args:
        origin_path: Path to the origin dataset directory
        target_dataset_path: Path to the target dataset directory  
        classes: Dictionary mapping origin class indices to target class indices
    """
    import os
    
    # Define source and target label directories
    source_labels_dir = os.path.join(origin_path, "labels")
    target_labels_dir = os.path.join(target_dataset_path, "labels")
    
    # Check if source labels directory exists
    if not os.path.exists(source_labels_dir):
        print(f"❌ Source labels directory not found: {source_labels_dir}")
        return False
    
    # Create target labels directory if it doesn't exist
    os.makedirs(target_labels_dir, exist_ok=True)
    
    try:
        # Process each label file in the source directory
        for filename in os.listdir(source_labels_dir):
            source_file = os.path.join(source_labels_dir, filename)
            
            # Only process text files
            if os.path.isfile(source_file) and filename.endswith('.txt'):
                target_file = os.path.join(target_labels_dir, filename)
                
                # Read and transform the label file
                transformed_lines = []
                
                with open(source_file, 'r') as f:
                    for line in f:
                        line = line.strip()
                        if not line:  # Skip empty lines
                            continue
                            
                        # Split the line into parts
                        parts = line.split()
                        if len(parts) < 5:  # YOLO format requires at least class + 4 coordinates
                            continue
                            
                        try:
                            # Extract the class number (first value)
                            origin_class = int(parts[0])
                            
                            # Check if this class is in our mapping
                            if origin_class in classes:
                                # Map to target class
                                target_class = classes[origin_class]
                                
                                # Create new line with mapped class and same coordinates
                                new_line = f"{target_class} {' '.join(parts[1:])}"
                                transformed_lines.append(new_line)
                            # If class not in mapping, drop the line (as requested)
                            
                        except ValueError:
                            # Skip lines that don't have valid integer class
                            continue
                
                # Write the transformed content to target file
                with open(target_file, 'w') as f:
                    f.write('\n'.join(transformed_lines))
                
                print(f"✅ Transformed: {filename} ({len(transformed_lines)} lines kept)")
        
        print(f"✅ Successfully transformed all labels from {source_labels_dir} to {target_labels_dir}")
        return True
        
    except Exception as e:
        print(f"❌ Error transforming labels: {str(e)}")
        return False

def process_dataset(dataset: str, classes: Dict[int, int], target_dataset_path: str):
    copy_images(dataset, target_dataset_path)
    transform_and_copy_labels(dataset, target_dataset_path, classes)
    pass

def process_origin(dataset, target_classes, target_dataset_path):
    mapped_classes = map_classes(dataset.fields_map, target_classes, extract_origin_classes(dataset))
    process_dataset(dataset.origin + "/test", mapped_classes, target_dataset_path + "/test")
    process_dataset(dataset.origin + "/valid", mapped_classes, target_dataset_path + "/valid")
    process_dataset(dataset.origin + "/train", mapped_classes, target_dataset_path + "/train")


def process_origins(config):
    for dataset in config["datasets"]:
        print("--------------------------------")
        print(dataset)
        print(config["target_classes"])
        print(config["target_dataset_path"])
        process_origin(dataset, config["target_classes"], config["target_dataset_path"])

# %%
# Load the configuration with the new structure
config = load_config_mappings("config.yml")
generate_target_dataset_path(config)
generate_target_yolo_data_file(config)
process_origins(config)
# Out:
# [container]
# --------------------------------
# origin='/home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11' fields_map=[FieldMapping(source_field='0', target_field='container')]
# ['container']
# ./testing
# ❌ Source images directory not found: /home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11/test/images
# ❌ Source labels directory not found: /home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11/test/labels
# ❌ Source images directory not found: /home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11/valid/images
# ❌ Source labels directory not found: /home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11/valid/labels
# ✅ Copied: 20240526_233610-640_Camera_4_jpg.rf.b63c7ed014c3c785499042adef2dfd10.jpg
# ✅ Copied: 20240529_202717-223_Camera_5_jpg.rf.554f8f20f07888d873a9e2b792c88800.jpg
# ✅ Copied: 20240524_203220-523_Camera_9_jpg.rf.e30a7b39b1e24d55d5ce11eb60ceedbb.jpg
# ✅ Copied: 20240525_142707-659_Camera_5_jpg.rf.0ac005b0efe22ac0c4f81f2eba679f4d.jpg
# ✅ Copied: 20240601_010924-843_Camera_4_jpg.rf.491ef739204f6d585329071be03000d0.jpg
# ✅ Copied: 20240603_014244-250_Camera_3_jpg.rf.9f1eda0f30b73194f9fdf940885e2fec.jpg
# ✅ Copied: 20240528_234504-294_Camera_4_jpg.rf.bb82d2edceada3c6885f622c886d74bd.jpg
# ✅ Copied: 20240520_062528-871_Camera_5_jpg.rf.65e6fb4cba7fbe92bc3bc54f7dcd7761.jpg
# ✅ Copied: 20240529_165827-565_Camera_5_jpg.rf.fc5208cb5bcdc22f22f4e53c189af107.jpg
# ✅ Copied: 20240529_171831-945_Camera_3_jpg.rf.da68d26ffdbd59636e93e8220131b278.jpg
# ✅ Copied: 20240526_225158-555_Camera_3_jpg.rf.dd00fff1e4c825de88adb57bd28dfe6c.jpg
# ✅ Copied: 20240529_171523-896_Camera_4_jpg.rf.5fca6e35454866d30fad85f867c86225.jpg
# ✅ Copied: 20240522_073816-908_Camera_4_jpg.rf.778a201274c8970e686067f9bded6e23.jpg
# ✅ Copied: 20240529_201212-324_Camera_4_jpg.rf.8dbb37ca8839d41e6297489ce551a4d7.jpg
# ✅ Copied: 20240529_005804-830_Camera_9_jpg.rf.c6e7f273093914d093acf641c7e02d19.jpg
# ✅ Copied: 20240524_205909-2_Camera_9_jpg.rf.37ace41a573e1b0071d684e709b0b5bc.jpg
# ✅ Copied: 20240522_062205-757_Camera_4_jpg.rf.7e3ccd7e5254f5d867f50f089ff90f51.jpg
# ✅ Copied: 20240525_163507-133_Camera_5_jpg.rf.34d7bb2aebc201b1b652b764dc75d367.jpg
# ✅ Copied: 20240524_233745-416_Camera_3_jpg.rf.5f0040c2dfbdcb600a225167add5a099.jpg
# ✅ Copied: 20240603_013943-835_Camera_4_jpg.rf.0541708cff2c01b5a7a9d8060ce7e723.jpg
# ✅ Copied: 20240519_101929-25_Camera_3_jpg.rf.28413b5a3ecc3c3117c7770f7fbe708b.jpg
# ✅ Copied: 20240529_164341-858_Camera_5_jpg.rf.94e7d5d85c931ed29782d5fe8825302f.jpg
# ✅ Copied: 20240528_223639-884_Camera_9_jpg.rf.e903c895952457ef9957ec71a7519c03.jpg
# ...
# ✅ Transformed: 20240526_184139-137_Camera_4_jpg.rf.c0b8c7c79222164208a45c24bb018a04.txt (1 lines kept)
# ✅ Transformed: 20240528_231700-676_Camera_5_jpg.rf.4abb42567f2b85475290bf6f08c5dc76.txt (1 lines kept)
# ✅ Transformed: 20240521_040812-354_Camera_5_jpg.rf.0721de7c37a29403f8a360f813ce7d7b.txt (1 lines kept)
# ✅ Transformed: 20240522_082727-699_Camera_3_jpg.rf.10be4545241072c043ce5440eb4f62c2.txt (1 lines kept)
# ✅ Transformed: 20240524_214440-180_Camera_5_jpg.rf.f52d0581364a19617e7665108e2d8941.txt (1 lines kept)
# ✅ Transformed: 20240529_203147-709_Camera_4_jpg.rf.7712a5d65476531d9bb3f283210405f1.txt (1 lines kept)
# ✅ Transformed: 20240529_155856-821_Camera_3_jpg.rf.583b15b3d5b5979c17c22a138b492c8b.txt (1 lines kept)
# ✅ Transformed: 20240519_105351-268_Camera_4_jpg.rf.6897a61ca4d2c31421ac6269ccaeb271.txt (2 lines kept)
# ✅ Transformed: 20240524_203751-913_Camera_9_jpg.rf.10c37a1c53eb7514d1c3645b9db83d0e.txt (1 lines kept)
# ✅ Transformed: 20240522_072729-869_Camera_3_jpg.rf.ef806280952d1859ee3cca84de184ef3.txt (1 lines kept)
# ✅ Transformed: 20240521_040812-289_Camera_4_jpg.rf.f650c8814ed177987038fdc3f71e00fb.txt (1 lines kept)
# ✅ Transformed: 20240529_003555-339_Camera_4_jpg.rf.63b2819a94f1af7c6d28ebf622ff4013.txt (1 lines kept)
# ✅ Transformed: 20240529_223146-902_Camera_5_jpg.rf.3a6d36fcd6f7d0a5fa7628e0b8bab969.txt (1 lines kept)
# ✅ Transformed: 20240601_044847-486_Camera_5_jpg.rf.e4133fd42d49efac289c92cf5d6f70ac.txt (1 lines kept)
# ✅ Transformed: 20240528_215605-140_Camera_4_jpg.rf.fa94635362258e1d4d516d1e7f849d99.txt (1 lines kept)
# ✅ Transformed: 20240528_224325-903_Camera_4_jpg.rf.7de01ee797a363740b299a65abd17ed2.txt (1 lines kept)
# ✅ Transformed: 20240529_193844-961_Camera_5_jpg.rf.974717cf1792847437726e24578ad2ec.txt (1 lines kept)
# ✅ Transformed: 20240525_152501-514_Camera_4_jpg.rf.a7fb6bf779b306d709f5f8536e65ecdf.txt (1 lines kept)
# ✅ Transformed: 20240522_064105-161_Camera_5_jpg.rf.2f71344a0aa375e142a16770950c078b.txt (1 lines kept)
# ✅ Transformed: 20240521_063726-196_Camera_5_jpg.rf.f13dd387dbdad19e4d0e5e79d232d8fc.txt (1 lines kept)
# ✅ Transformed: 20240522_080349-27_Camera_5_jpg.rf.12a23a495351df7fdc69071a2fbcaab2.txt (2 lines kept)
# ✅ Transformed: 20240526_231445-835_Camera_5_jpg.rf.f0bcdc1866a17e2ff836ae9594697f9d.txt (2 lines kept)
# ✅ Transformed: 20240526_212746-965_Camera_3_jpg.rf.77bfd7f0c6813870474daa259201310c.txt (1 lines kept)
# ✅ Transformed: 20240520_065846-276_Camera_4_jpg.rf.4fbe7be95e5c38d1e6b06851ccaa4cf8.txt (1 lines kept)
# ✅ Transformed: 20240519_113235-515_Camera_4_jpg.rf.75ecf9d7c727b7e513781d94f8641523.txt (1 lines kept)
# ✅ Transformed: 20240526_212238-414_Camera_5_jpg.rf.4e2f26442493a633d1883d0c7ca6a49c.txt (2 lines kept)
# ✅ Transformed: 20240529_190127-955_Camera_5_jpg.rf.609e0a46e2b3903fb51778c8dfe16d70.txt (1 lines kept)
# ✅ Transformed: 20240529_041002-401_Camera_3_jpg.rf.bd84457dde4cd176a3755554b193f0dc.txt (1 lines kept)
# ✅ Transformed: 20240601_064838-455_Camera_4_jpg.rf.0375bcb455867bfa4f00fc0cf60c5369.txt (1 lines kept)
# ✅ Transformed: 20240529_030958-389_Camera_3_jpg.rf.65eff25e6210892eabb00bfae23992fb.txt (1 lines kept)
# ✅ Transformed: 20240526_190416-991_Camera_4_jpg.rf.67d6c442e8198306cc2fc318b65c81d9.txt (1 lines kept)
# ✅ Transformed: 20240601_024430-612_Camera_4_jpg.rf.5b11fa0b8b552871b668914ab0e63236.txt (1 lines kept)
# ✅ Transformed: 20240526_192044-265_Camera_9_jpg.rf.cc2dd506e39da5c14efd5102759f9138.txt (1 lines kept)
# ✅ Transformed: 20240522_082012-914_Camera_4_jpg.rf.830169a6a89919171201260b182b01f5.txt (1 lines kept)
# ✅ Transformed: 20240526_191011-546_Camera_9_jpg.rf.e4d176ece0c4653098b34ba046c6dc3f.txt (1 lines kept)
# ✅ Transformed: 20240601_005236-38_Camera_4_jpg.rf.e277bbd4a6023d3a56aeef4528023fb3.txt (1 lines kept)
# ✅ Transformed: 20240526_185419-159_Camera_5_jpg.rf.4648a26e515bc833dd1e762281188ff5.txt (1 lines kept)
# ✅ Transformed: 20240529_185433-11_Camera_9_jpg.rf.2266df8269347928ce1867f88eef830a.txt (1 lines kept)
# ✅ Transformed: 20240522_070443-527_Camera_5_jpg.rf.313b62698a86116c3273411310183fca.txt (1 lines kept)
# ✅ Transformed: 20240601_063049-888_Camera_4_jpg.rf.d5c2a2eb816f72d698329ead423cbfc0.txt (1 lines kept)
# ✅ Transformed: 20240529_154545-260_Camera_3_jpg.rf.2a004a007af16cbff9528b4c77d9739b.txt (1 lines kept)
# ✅ Transformed: 20240529_190002-849_Camera_4_jpg.rf.0fd53eb90d8f8cac47458ecfd01df803.txt (1 lines kept)
# ✅ Transformed: 20240528_233535-890_Camera_4_jpg.rf.7e2debf98ef6267b3c29d28590d68cb4.txt (1 lines kept)
# ✅ Transformed: 20240601_054511-87_Camera_5_jpg.rf.fe75144850d7506cf3051709161cc82c.txt (1 lines kept)
# ✅ Transformed: 20240524_213426-94_Camera_4_jpg.rf.e6bd7041de1aae143ce0689a38da068b.txt (1 lines kept)
# ✅ Transformed: 20240524_220440-3_Camera_5_jpg.rf.978aae27bbdb008c8799f3430ffe3b1b.txt (1 lines kept)
# ✅ Transformed: 20240526_220844-591_Camera_4_jpg.rf.30a7a2c634fc5490dd801288de1f6d3c.txt (1 lines kept)
# ✅ Transformed: 20240529_192647-289_Camera_9_jpg.rf.0083bdc2179c9e86f31fda328964a46b.txt (1 lines kept)
# ✅ Transformed: 20240524_213637-70_Camera_9_jpg.rf.02cd220788e48604ac3d5d39e6d3dbea.txt (1 lines kept)
# ✅ Transformed: 20240522_071219-622_Camera_9_jpg.rf.10d687507f8c8f2a1e94b8b054d3d1f2.txt (1 lines kept)
# ✅ Transformed: 20240529_184225-369_Camera_3_jpg.rf.4c3bd61eb5eeaa5e783b5e3336829ab2.txt (1 lines kept)
# ✅ Transformed: 20240527_054558-773_Camera_3_jpg.rf.c26f487bff1d54fc0c4ee304dc7682a6.txt (1 lines kept)
# ✅ Transformed: 20240526_200956-720_Camera_3_jpg.rf.f29ee71564ae5f69448f0bfe06630a43.txt (1 lines kept)
# ✅ Transformed: 20240524_232605-549_Camera_4_jpg.rf.7fb396700032bed58808ebc660156f1b.txt (1 lines kept)
# ✅ Transformed: 20240529_014203-815_Camera_3_jpg.rf.69410d9b08e221b94ef0d7a55b160486.txt (1 lines kept)
# ✅ Transformed: 20240524_215721-836_Camera_3_jpg.rf.10bf61521af7e5aa5c2c27fd73614ded.txt (1 lines kept)
# ✅ Transformed: 20240524_234039-984_Camera_5_jpg.rf.239df40afd4f37c4e23f59e664535921.txt (1 lines kept)
# ✅ Transformed: 20240529_165304-745_Camera_5_jpg.rf.8fcf987df7c4201125ba9d240890f843.txt (1 lines kept)
# ✅ Transformed: 20240522_075531-917_Camera_3_jpg.rf.1c8d6c01aad2d25cc9339f3da2da541a.txt (1 lines kept)
# ✅ Transformed: 20240519_101107-93_Camera_3_jpg.rf.aa045c9950971b02ba1c1347ff1a5700.txt (1 lines kept)
# ✅ Transformed: 20240526_212746-937_Camera_5_jpg.rf.7669b324dda99023cd670d060645bb96.txt (1 lines kept)
# ✅ Transformed: 20240519_113847-981_Camera_5_jpg.rf.38febff149a345df16f21aa767edb9db.txt (1 lines kept)
# ✅ Transformed: 20240521_042612-837_Camera_3_jpg.rf.80bc94a66145635e7a251b2b61385d35.txt (1 lines kept)
# ✅ Transformed: 20240529_161337-726_Camera_9_jpg.rf.1cde0cf4742d641f63795148337aaf43.txt (1 lines kept)
# ✅ Transformed: 20240529_185346-992_Camera_4_jpg.rf.a749645d1543cb837f8d5992171f9a34.txt (1 lines kept)
# ✅ Transformed: 20240529_170250-638_Camera_5_jpg.rf.e65667ef8341493193a891fc8ecd5fb0.txt (2 lines kept)
# ✅ Transformed: 20240526_200600-84_Camera_4_jpg.rf.7df1d9527302fc7737a093c4b4f5754b.txt (1 lines kept)
# ✅ Transformed: 20240520_090710-635_Camera_4_jpg.rf.2d36cdc90c50d4b5c0814f304a8ced51.txt (1 lines kept)
# ✅ Transformed: 20240529_020709-456_Camera_9_jpg.rf.0d8a43e3ffcd21e1414aba92691bd4be.txt (1 lines kept)
# ✅ Transformed: 20240601_042203-500_Camera_4_jpg.rf.20dc1c5397dada803b2179cbcc85c8d0.txt (1 lines kept)
# ✅ Transformed: 20240529_193037-835_Camera_3_jpg.rf.5a79990683b04a21c77fed46c03ec71f.txt (1 lines kept)
# ✅ Transformed: 20240601_031856-818_Camera_3_jpg.rf.e55c362379f870a836509ac84832cea7.txt (1 lines kept)
# ✅ Transformed: 20240519_121519-39_Camera_4_jpg.rf.95b3da36c1168e8b0b23cb588f3b3a5c.txt (1 lines kept)
# ✅ Transformed: 20240522_052522-374_Camera_4_jpg.rf.346f1206845c57b6d6f40f385978deba.txt (1 lines kept)
# ✅ Transformed: 20240603_082231-572_Camera_5_jpg.rf.0610f6112433167b142d036f512493e2.txt (1 lines kept)
# ✅ Transformed: 20240529_194057-351_Camera_9_jpg.rf.1a21e697a8a9e6b8e43a6743705589e2.txt (1 lines kept)
# ✅ Transformed: 20240519_093734-928_Camera_3_jpg.rf.5520246ae1643ac1802f1929d46b151c.txt (1 lines kept)
# ✅ Transformed: 20240529_154500-665_Camera_5_jpg.rf.b2ede8187331f46bde0ebbba2673c780.txt (1 lines kept)
# ✅ Transformed: 20240603_071342-927_Camera_4_jpg.rf.0f647308a8176ca4696767847871a8d8.txt (1 lines kept)
# ✅ Transformed: 20240603_021624-825_Camera_4_jpg.rf.e64fbaa1e3c9911dedc50e6a2e1c4996.txt (1 lines kept)
# ✅ Transformed: 20240522_062624-662_Camera_9_jpg.rf.888c54df93114fc7e619fc56e4e03f22.txt (1 lines kept)
# ✅ Transformed: 20240521_084250-155_Camera_4_jpg.rf.49c53aefbfe473a7ea45d8567aeee754.txt (1 lines kept)
# ✅ Transformed: 20240524_225559-863_Camera_3_jpg.rf.ed8dee88ebe3f785f60de3fbfb2d1074.txt (1 lines kept)
# ✅ Transformed: 20240522_044231-745_Camera_5_jpg.rf.09cbdf0045e3d2780da8fbef9a640b94.txt (1 lines kept)
# ✅ Transformed: 20240527_063614-859_Camera_4_jpg.rf.d2c2244bb9ff084b6c71d942bdbacdc3.txt (1 lines kept)
# ✅ Transformed: 20240525_155842-244_Camera_4_jpg.rf.273d45aa0e1370f82f138584486a8876.txt (1 lines kept)
# ✅ Transformed: 20240529_165827-565_Camera_5_jpg.rf.fc5208cb5bcdc22f22f4e53c189af107.txt (1 lines kept)
# ✅ Transformed: 20240527_060911-392_Camera_4_jpg.rf.13fe106f03c9a9ba7cc98d403dd14a69.txt (1 lines kept)
# ✅ Transformed: 20240603_015153-998_Camera_4_jpg.rf.2aea88b7a85fd68bc9c246aa7bb7f442.txt (1 lines kept)
# ✅ Transformed: 20240526_191219-229_Camera_5_jpg.rf.74c07dda69615a8d70da452fd778c207.txt (1 lines kept)
# ✅ Transformed: 20240529_192647-210_Camera_4_jpg.rf.94339685199d44803704f3b6e7ab13f0.txt (1 lines kept)
# ✅ Transformed: 20240527_064323-374_Camera_4_jpg.rf.daac9d74453270e750b7eff54a3752f9.txt (1 lines kept)
# ✅ Transformed: 20240525_170419-494_Camera_4_jpg.rf.97dc84cc83c1ca58a89cf6834dc01b7d.txt (1 lines kept)
# ✅ Transformed: 20240522_083808-647_Camera_3_jpg.rf.c73483d947d891c8eacae6c160e0d6db.txt (1 lines kept)
# ✅ Transformed: 20240520_074345-174_Camera_4_jpg.rf.bc94fdabcd19c1f36a56fa442234224d.txt (1 lines kept)
# ✅ Transformed: 20240522_071652-552_Camera_5_jpg.rf.28c4b7297405d813a9772bdc8054b16c.txt (1 lines kept)
# ✅ Transformed: 20240601_023430-883_Camera_5_jpg.rf.8d64757164960a7cfe30352c82d148f1.txt (1 lines kept)
# ✅ Transformed: 20240601_060607-298_Camera_4_jpg.rf.271759cb75e8ae1b8e0cbabf69b62d82.txt (1 lines kept)
# ✅ Transformed: 20240529_162652-224_Camera_3_jpg.rf.ac06fde4ee55ce8c1d91aab1a6a98ea3.txt (1 lines kept)
# ✅ Transformed: 20240520_062655-927_Camera_4_jpg.rf.c6c2a713d9de8564994d8fb0bf88a47c.txt (1 lines kept)
# ✅ Transformed: 20240529_194801-106_Camera_4_jpg.rf.68e8803c817823ab1771d885eee21d85.txt (1 lines kept)
# ✅ Transformed: 20240524_210120-78_Camera_3_jpg.rf.75892207beb461e7c9ad67f729a0e001.txt (1 lines kept)
# ✅ Transformed: 20240528_230332-29_Camera_5_jpg.rf.9a88b23420ef801848db30383439911e.txt (1 lines kept)
# ✅ Transformed: 20240526_212746-965_Camera_3_jpg.rf.338925734dd3def99027c26c86688295.txt (1 lines kept)
# ✅ Transformed: 20240529_020556-209_Camera_3_jpg.rf.17d246fd39c079eb774a61aa70079c5f.txt (1 lines kept)
# ✅ Transformed: 20240519_114551-673_Camera_3_jpg.rf.dcaec06f8cc5ed1606466972331d2b25.txt (1 lines kept)
# ✅ Transformed: 20240520_064517-820_Camera_4_jpg.rf.0f1816859a99342385cdcc56d67c644d.txt (1 lines kept)
# ✅ Transformed: 20240529_202717-223_Camera_5_jpg.rf.554f8f20f07888d873a9e2b792c88800.txt (1 lines kept)
# ✅ Transformed: 20240529_172238-408_Camera_3_jpg.rf.dd7d4b4f12dc838bb59debbf22e51171.txt (1 lines kept)
# ✅ Transformed: 20240601_014306-356_Camera_4_jpg.rf.65ec139002f0cbb34351093527f514a3.txt (1 lines kept)
# ✅ Transformed: 20240520_080909-719_Camera_4_jpg.rf.e82dd5f133113ce67a2de5880599eb88.txt (1 lines kept)
# ✅ Transformed: 20240524_223445-951_Camera_9_jpg.rf.5592bee75c547c33c84b24978db3f011.txt (1 lines kept)
# ✅ Transformed: 20240521_032403-704_Camera_4_jpg.rf.28506d9b6c7fe9cb0715bf999b66b70b.txt (1 lines kept)
# ✅ Transformed: 20240521_053912-287_Camera_4_jpg.rf.4e421b9e704a16b9ac20b302bd56f5a0.txt (1 lines kept)
# ✅ Transformed: 20240522_065059-771_Camera_5_jpg.rf.4406d9a0aa6ddca72ebbae4f34ebbf25.txt (1 lines kept)
# ✅ Transformed: 20240525_160143-995_Camera_5_jpg.rf.9384e35ba71edf2689094480b254c02e.txt (1 lines kept)
# ✅ Transformed: 20240524_201935-182_Camera_5_jpg.rf.2d28f4c2c6f377e674ceaf3bd14d3531.txt (1 lines kept)
# ✅ Transformed: 20240603_075811-968_Camera_5_jpg.rf.47ff68def3a50fb9e6ca8167f933d6fc.txt (1 lines kept)
# ✅ Transformed: 20240526_223858-670_Camera_3_jpg.rf.ffd49029cbbd0ffcff8dcbd4b1ba95b4.txt (1 lines kept)
# ✅ Transformed: 20240524_230032-743_Camera_4_jpg.rf.fe8da9332ea76c5d1260e590ee7006aa.txt (1 lines kept)
# ✅ Transformed: 20240524_232605-534_Camera_5_jpg.rf.79e332d58b1e46eb9b0f7912b2b75b44.txt (1 lines kept)
# ✅ Transformed: 20240526_200832-562_Camera_5_jpg.rf.4be02faae685ec62ed016371b8c616a0.txt (1 lines kept)
# ✅ Transformed: 20240520_075327-496_Camera_4_jpg.rf.844db901bd8008328d18097f28d42ce2.txt (1 lines kept)
# ✅ Transformed: 20240522_045503-74_Camera_3_jpg.rf.0d0ea695eecadce21ff83f33ff46d2b5.txt (1 lines kept)
# ✅ Transformed: 20240601_005713-666_Camera_5_jpg.rf.159b4431d7471a0012cdd1c3ce21d4f2.txt (1 lines kept)
# ✅ Transformed: 20240526_223619-661_Camera_4_jpg.rf.0e1922590f9f5e812c40381ddfcbcf84.txt (1 lines kept)
# ✅ Transformed: 20240601_053123-41_Camera_4_jpg.rf.0e3fd5279ba395ef49bdb2f5678f5250.txt (1 lines kept)
# ✅ Transformed: 20240524_233353-109_Camera_4_jpg.rf.48b8c9ee5c19e0f6286e0ec94a47ce93.txt (1 lines kept)
# ✅ Transformed: 20240521_033817-798_Camera_4_jpg.rf.d371ae8726b582e1146b42a7b4a027f7.txt (1 lines kept)
# ✅ Transformed: 20240520_093717-175_Camera_3_jpg.rf.50b8685991e9eda5514e77e9a57665bf.txt (2 lines kept)
# ✅ Transformed: 20240524_222617-998_Camera_9_jpg.rf.3646b33e89d5f778bece01f2fdacd98f.txt (1 lines kept)
# ✅ Transformed: 20240519_095253-570_Camera_4_jpg.rf.218d4d66629bc660e5716b9b1e223a53.txt (1 lines kept)
# ✅ Transformed: 20240529_215931-371_Camera_4_jpg.rf.93efd889bef7d79a8e8f22daf9b5d699.txt (1 lines kept)
# ✅ Transformed: 20240519_095656-769_Camera_4_jpg.rf.4a4d0f4cf29bb3fe4d209c58e7878a06.txt (1 lines kept)
# ✅ Transformed: 20240525_140657-681_Camera_4_jpg.rf.ec252418b48bef0fb40ec90b7eda64fc.txt (1 lines kept)
# ✅ Transformed: 20240529_165844-498_Camera_4_jpg.rf.c149de780ce4d86d863afb05c0667490.txt (1 lines kept)
# ✅ Transformed: 20240601_033509-646_Camera_3_jpg.rf.183ea75bafa0536df47e1e146b66f4f4.txt (1 lines kept)
# ✅ Transformed: 20240524_212631-734_Camera_5_jpg.rf.d0d97655911582c393bbacbb26d6a5bd.txt (1 lines kept)
# ✅ Transformed: 20240529_171452-487_Camera_3_jpg.rf.7d973c779f60dbe948dfdeb01ad286a7.txt (1 lines kept)
# ✅ Transformed: 20240526_211310-460_Camera_9_jpg.rf.b2414d4b39a513898515f3e689a9f262.txt (1 lines kept)
# ✅ Transformed: 20240520_084703-306_Camera_5_jpg.rf.dc1e72263f86a861803b1476a07208c6.txt (1 lines kept)
# ✅ Transformed: 20240522_084638-935_Camera_5_jpg.rf.6cf03b6cae505a15ea18bf094bb53805.txt (2 lines kept)
# ✅ Transformed: 20240525_173034-311_Camera_4_jpg.rf.d086ef39e628292f4228adeca6e5b31a.txt (1 lines kept)
# ✅ Transformed: 20240526_191011-546_Camera_9_jpg.rf.114a815859e000de0fe5115e5ec6b133.txt (1 lines kept)
# ✅ Transformed: 20240526_200956-767_Camera_9_jpg.rf.0c8e69c5d19ad6fb0a47f5598879faf7.txt (1 lines kept)
# ✅ Transformed: 20240529_165539-443_Camera_5_jpg.rf.d7730666de223997a46c18fdd2a0d771.txt (1 lines kept)
# ✅ Transformed: 20240601_054049-112_Camera_4_jpg.rf.4db1f725b9257cccefdcb82edda44384.txt (1 lines kept)
# ✅ Transformed: 20240528_224510-466_Camera_9_jpg.rf.2ec0d03cc68a9b494f25b3c4546e99c2.txt (1 lines kept)
# ✅ Transformed: 20240522_063633-896_Camera_5_jpg.rf.c2dd270d29375afbe55952075ba79b32.txt (1 lines kept)
# ✅ Transformed: 20240526_225722-886_Camera_4_jpg.rf.54e5a5b125d1cc847b7ac42fe2e4a5f8.txt (1 lines kept)
# ✅ Transformed: 20240525_001340-569_Camera_4_jpg.rf.537e42da6232bd02cd7f09ad941c3d52.txt (1 lines kept)
# ✅ Transformed: 20240522_092035-252_Camera_3_jpg.rf.d24b785f7b279abc18f1e05d3664ec6c.txt (1 lines kept)
# ✅ Transformed: 20240526_222408-126_Camera_3_jpg.rf.bc25524dbebc21c903408d2993fd73a4.txt (1 lines kept)
# ✅ Transformed: 20240524_205252-562_Camera_5_jpg.rf.755e68311b50954a3d4d7b5daf36c0ac.txt (1 lines kept)
# ✅ Successfully transformed all labels from /home/emma/facultad/pps/datasets/containers/raw/container.v1i.yolov11/train/labels to ./testing/train/labels
