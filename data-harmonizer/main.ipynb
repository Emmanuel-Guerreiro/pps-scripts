# %%
# Data Harmonizer - Pydantic Models and Configuration Loading
# This notebook demonstrates how to load and work with data harmonization configurations

from pydantic import BaseModel
from typing import List
import yaml

# %%
class FieldMapping(BaseModel):
    """Represents a single field mapping between source and target."""
    source_field: str
    target_field: str


class DataMapping(BaseModel):
    """Represents a complete data mapping configuration."""
    origin: str
    fields_map: List[FieldMapping]

# %%
def load_config_mappings(config_path: str) -> dict:
    """
    Load configuration from YAML file and convert to dict with target_classes, target_dataset_path and datasets.
    
    Args:
        config_path: Path to the YAML configuration file
        
    Returns:
        Dict with target_classes, target_dataset_path and datasets fields
    """
    with open(config_path, 'r') as file:
        config_data = yaml.safe_load(file)
    
    # Convert datasets to Pydantic objects
    datasets = []
    for mapping_config in config_data["datasets"]:
        # Convert each mapping to Pydantic objects
        field_mappings = [
            FieldMapping(
                source_field=field["source_field"],
                target_field=field["target_field"]
            )
            for field in mapping_config["fields_map"]
        ]
        
        data_mapping = DataMapping(
            origin=mapping_config["origin"],
            fields_map=field_mappings
        )
        datasets.append(data_mapping)
    
    return {
        "target_classes": config_data["target_classes"],
        "target_dataset_path": config_data["target_dataset_path"],
        "datasets": datasets,
        "target_size": config_data["target_size"]
    }

# %%
import os
def generate_internal_structure(config, step_path):
    if not os.path.exists(config["target_dataset_path"] + f"/{step_path}" + "/images"):
        os.makedirs(config["target_dataset_path"] + f"/{step_path}" + "/images")
    if not os.path.exists(config["target_dataset_path"] + f"/{step_path}" + "/labels"):
        os.makedirs(config["target_dataset_path"] + f"/{step_path}" + "/labels")

def generate_target_dataset_path(config):
    if not os.path.exists(config["target_dataset_path"]):
        os.makedirs(config["target_dataset_path"])
    generate_internal_structure(config, "train")
    generate_internal_structure(config, "valid")
    generate_internal_structure(config, "test")
    
    return config["target_dataset_path"]

# %%
def generate_target_yolo_data_file(config):
    import yaml
    import os
    
    data_yaml_path = os.path.join(config["target_dataset_path"], "data.yaml")
    names = f"[{', '.join(config["target_classes"])}]"
    print(names)
    # Create the YOLO data structure
    yolo_data = {
        'train': '../train/images',
        'val': '../valid/images', 
        'test': '../test/images',
        'nc': len(config["target_classes"]),
        'names': names
    }
    
    if not os.path.exists(data_yaml_path):
        with open(data_yaml_path, "w") as file:
            yaml.dump(yolo_data, file)
    
    return data_yaml_path

# %%
def filter_segmentation_labels(target_dataset_path: str):
    """
    Filter out segmentation labels and keep only bounding box labels.
    In YOLO format:
    - Bounding box: <class_id> <x_center> <y_center> <width> <height> (5 items)
    - Segmentation: <class_id> <x1> <y1> <x2> <y2> ... (more than 5 items)
    
    Args:
        target_dataset_path: Path to the target dataset directory
    """
    import os
    
    split_names = ['train', 'valid', 'test']
    
    for split in split_names:
        labels_dir = os.path.join(target_dataset_path, split, "labels")
        images_dir = os.path.join(target_dataset_path, split, "images")
        
        if not os.path.exists(labels_dir):
            continue
        
        files_to_remove = []
        
        # Process each label file
        for filename in os.listdir(labels_dir):
            if not filename.endswith('.txt'):
                continue
                
            label_file = os.path.join(labels_dir, filename)
            
            with open(label_file, 'r') as f:
                lines = f.readlines()
            
            # Filter lines to keep only bounding boxes (exactly 5 items)
            filtered_lines = []
            for line in lines:
                line = line.strip()
                if not line:
                    continue
                parts = line.split()
                # Keep only lines with exactly 5 items (bounding boxes)
                if len(parts) == 5:
                    filtered_lines.append(line)
            
            # Update the label file
            if filtered_lines:
                with open(label_file, 'w') as f:
                    f.write('\n'.join(filtered_lines))
                print(f"✅ Filtered {filename}: kept {len(filtered_lines)} bounding boxes (removed {len(lines) - len(filtered_lines)} segmentation lines)")
            else:
                # Mark for removal if no valid labels remain
                files_to_remove.append(filename)
                print(f"🗑️  Marking for removal: {filename} (only segmentation labels found)")
        
        # Remove images and labels with no valid bounding boxes
        if files_to_remove:
            for filename in files_to_remove:
                # Remove label file
                label_file = os.path.join(labels_dir, filename)
                if os.path.exists(label_file):
                    os.remove(label_file)
                    print(f"🗑️  Removed label: {filename}")
                
                # Remove corresponding image
                image_name = filename[:-4]  # Remove .txt extension
                for ext in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
                    image_file = os.path.join(images_dir, image_name + ext)
                    if os.path.exists(image_file):
                        os.remove(image_file)
                        print(f"🗑️  Removed image: {image_name + ext}")
                        break

# %%
from typing import Dict

def extract_origin_classes(dataset: DataMapping):
    yaml_path = dataset.origin + "/data.yaml"
    with open(yaml_path, 'r') as file:
        classes = yaml.safe_load(file)
    
    if "names" not in classes:
        raise ValueError(f"❌ 'names' field not found in {yaml_path}. Available keys: {list(classes.keys())}")
    
    origin_names = classes["names"]
    print(f"📋 Origin dataset classes from {yaml_path}: {origin_names}")
    return origin_names

def map_classes(config_classes: List[FieldMapping], target_classes: List[str], origin_classes_list: List[str]) -> Dict[int, int]:
    """
     The result is a dict {idx_origin_class: idx_target_class}
     The idea is that this mapping will be used to map the classes of the origin dataset to the target dataset
     If a source_field is not found in the origin dataset, it will be skipped (ignored)
    """
    origin_classes_indexed = {origin_classes_list[i]: i for i in range(len(origin_classes_list))}
    target_classes_indexed = {target_classes[i]: i for i in range(len(target_classes))}

    result = {}
    for config_class in config_classes:
        # Check if source field exists in origin dataset
        if config_class.source_field not in origin_classes_indexed:
            print(f"⚠️  Skipping '{config_class.source_field}' - not found in origin dataset classes: {origin_classes_list}")
            continue
        
        # Check if target field exists in target classes
        if config_class.target_field not in target_classes_indexed:
            print(f"⚠️  Skipping '{config_class.source_field}' -> '{config_class.target_field}' - target field not found in target classes: {target_classes}")
            continue
        
        result[origin_classes_indexed[config_class.source_field]] = target_classes_indexed[config_class.target_field]
    
    return result

def copy_and_resize_images(origin_path: str, target_dataset_path: str, target_size: int):
    """
    Copy and resize images from origin to target dataset.
    
    Args:
        origin_path: Path to the origin dataset directory
        target_dataset_path: Path to the target dataset directory
        target_size: Size for the square output (e.g., 640 for 640x640)
    """
    import os
    import cv2
    
    # Define source and target image directories
    source_images_dir = os.path.join(origin_path, "images")
    target_images_dir = os.path.join(target_dataset_path, "images")
    
    # Check if source images directory exists
    if not os.path.exists(source_images_dir):
        print(f"❌ Source images directory not found: {source_images_dir}")
        return False
    
    # Create target images directory if it doesn't exist
    os.makedirs(target_images_dir, exist_ok=True)
    
    # Get list of image files
    image_files = [f for f in os.listdir(source_images_dir) 
                   if f.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff"))]
    
    if not image_files:
        print(f"❌ No image files found in {source_images_dir}")
        return False
    
    print(f"🔄 Processing {len(image_files)} images...")
    
    # Define the new size as a square
    new_size = (target_size, target_size)
    
    processed_count = 0
    try:
        for filename in image_files:
            source_file = os.path.join(source_images_dir, filename)
            target_file = os.path.join(target_images_dir, filename)
            
            # Only process files (not directories)
            if os.path.isfile(source_file):
                # Read the image
                img = cv2.imread(source_file)
                
                if img is None:
                    print(f"⚠️  Could not read image: {filename}")
                    continue
                
                # Resize the image
                resized = cv2.resize(img, new_size)
                
                # Save the resized image
                cv2.imwrite(target_file, resized)
                
                processed_count += 1
                # print(f"✅ Processed: {filename}")
        
        print(f"✅ Successfully processed {processed_count}/{len(image_files)} images to {target_size}x{target_size}")
        return processed_count > 0
        
    except Exception as e:
        print(f"❌ Error processing images: {str(e)}")
        return False

def transform_and_copy_labels(origin_path: str, target_dataset_path: str, classes: Dict[int, int]):
    """
    Transform and copy label files from origin to target dataset.
    
    Args:
        origin_path: Path to the origin dataset directory
        target_dataset_path: Path to the target dataset directory  
        classes: Dictionary mapping origin class indices to target class indices
        
    Returns:
        List of filenames (without extension) that had 0 transformed lines
    """
    import os
    
    # Define source and target label directories
    source_labels_dir = os.path.join(origin_path, "labels")
    target_labels_dir = os.path.join(target_dataset_path, "labels")
    
    # Check if source labels directory exists
    if not os.path.exists(source_labels_dir):
        print(f"❌ Source labels directory not found: {source_labels_dir}")
        return []
    
    # Create target labels directory if it doesn't exist
    os.makedirs(target_labels_dir, exist_ok=True)
    
    # Track files with 0 transformed lines
    empty_files = []
    
    try:
        # Process each label file in the source directory
        for filename in os.listdir(source_labels_dir):
            source_file = os.path.join(source_labels_dir, filename)
            
            # Only process text files
            if os.path.isfile(source_file) and filename.endswith('.txt'):
                target_file = os.path.join(target_labels_dir, filename)
                
                # Read and transform the label file
                transformed_lines = []
                
                with open(source_file, 'r') as f:
                    for line in f:
                        line = line.strip()
                        if not line:  # Skip empty lines
                            continue
                            
                        # Split the line into parts
                        parts = line.split()
                        if len(parts) < 5:  # YOLO format requires at least class + 4 coordinates
                            continue
                            
                        try:
                            # Extract the class number (first value)
                            origin_class = int(parts[0])
                            
                            # Check if this class is in our mapping
                            if origin_class in classes:
                                # Map to target class
                                target_class = classes[origin_class]
                                
                                # Create new line with mapped class and same coordinates
                                new_line = f"{target_class} {' '.join(parts[1:])}"
                                transformed_lines.append(new_line)
                            # If class not in mapping, drop the line (as requested)
                            
                        except ValueError:
                            print(f"❌ Error transforming labels: {source_file}, line: {line}")
                            # Skip lines that don't have valid integer class
                            continue
                
                # Write the transformed content to target file
                with open(target_file, 'w') as f:
                    if len(transformed_lines) > 0:
                        f.write('\n'.join(transformed_lines))
                    else:
                        # Track files with 0 transformed lines
                        empty_files.append(filename[:-4])  # Remove .txt extension
                
                print(f"✅ Transformed: {filename} ({len(transformed_lines)} lines kept) from {origin_path}")
        
        print(f"✅ Successfully transformed all labels from {source_labels_dir} to {target_labels_dir}")
        return empty_files
        
    except Exception as e:
        print(f"❌ Error transforming labels: {str(e)}")
        return []

def remove_empty_images(target_dataset_path: str, empty_files: List[str]):
    """
    Remove images and labels corresponding to files that had 0 transformed lines.
    
    Args:
        target_dataset_path: Path to the target dataset directory
        empty_files: List of filenames (without extension) to remove
    """
    import os
    
    if not empty_files:
        return
    
    target_images_dir = os.path.join(target_dataset_path, "images")
    target_labels_dir = os.path.join(target_dataset_path, "labels")
    
    if not os.path.exists(target_images_dir):
        print(f"❌ Target images directory not found: {target_images_dir}")
        return
    
    if not os.path.exists(target_labels_dir):
        print(f"❌ Target labels directory not found: {target_labels_dir}")
        return
    
    removed_images = 0
    removed_labels = 0
    
    for filename in empty_files:
        # Remove corresponding image file
        for ext in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
            image_file = os.path.join(target_images_dir, filename + ext)
            if os.path.exists(image_file):
                try:
                    os.remove(image_file)
                    print(f"🗑️  Removed empty image: {filename + ext}")
                    removed_images += 1
                    break  # Found and removed, no need to try other extensions
                except Exception as e:
                    print(f"❌ Error removing image {filename + ext}: {str(e)}")
        
        # Remove corresponding label file
        label_file = os.path.join(target_labels_dir, filename + '.txt')
        if os.path.exists(label_file):
            try:
                os.remove(label_file)
                print(f"🗑️  Removed empty label: {filename + '.txt'}")
                removed_labels += 1
            except Exception as e:
                print(f"❌ Error removing label {filename + '.txt'}: {str(e)}")
    
    print(f"✅ Removed {removed_images} images and {removed_labels} labels with no useful content")

def process_dataset(dataset: str, classes: Dict[int, int], target_dataset_path: str, target_size: int):
    copy_and_resize_images(dataset, target_dataset_path, target_size)
    empty_files = transform_and_copy_labels(dataset, target_dataset_path, classes)
    print(f"Empty files: {empty_files}")
    remove_empty_images(target_dataset_path, empty_files)
    pass

def process_origin(dataset, target_classes, target_dataset_path, target_size):
    mapped_classes = map_classes(dataset.fields_map, target_classes, extract_origin_classes(dataset))
    process_dataset(dataset.origin + "/test", mapped_classes, target_dataset_path + "/test", target_size)
    # process_dataset(dataset.origin + "/valid", mapped_classes, target_dataset_path + "/valid", target_size)
    process_dataset(dataset.origin + "/train", mapped_classes, target_dataset_path + "/train", target_size)


def process_origins(config):
    for dataset in config["datasets"]:
        print("--------------------------------")
        print(dataset)
        print(config["target_classes"])
        print(config["target_dataset_path"])
        print(f"Target size: {config["target_size"]}x{config["target_size"]}")
        process_origin(dataset, config["target_classes"], config["target_dataset_path"], config["target_size"])

# %%
# Load the configuration with the new structure
config = load_config_mappings("./config.yml")
generate_target_dataset_path(config)
generate_target_yolo_data_file(config)
process_origins(config)

# filter_segmentation_labels(config["target_dataset_path"])
# Out:
# [no-eyewear, no-gloves, no-mask, person]
# --------------------------------
# origin='/home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11' fields_map=[FieldMapping(source_field='No - Goggles', target_field='no-eyewear'), FieldMapping(source_field='No - Gloves', target_field='no-gloves'), FieldMapping(source_field='Person', target_field='person')]
# ['no-eyewear', 'no-gloves', 'no-mask', 'person']
# /home/emma/facultad/pps/datasets/ppe-detection-yolov8-dataset
# Target size: 640x640
# 📋 Origin dataset classes from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/data.yaml: ['Gloves', 'Goggles', 'Helmet', 'No - Gloves', 'No - Goggles', 'No - Helmet', 'No - Safety Boots', 'No - Safety Vest', 'Person', 'Safety Boots', 'Safety Vest']
# 🔄 Processing 42 images...
# ✅ Successfully processed 42/42 images to 640x640
# ✅ Transformed: ppe-workers_34_png_jpg.rf.a55dd0a3fd2c954a14f7cd2711b0d53f.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: image_159_jpg.rf.f0598d9896b839952044785177d2fb92.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: building-workers_54_jpeg_jpg.rf.cd3154a2442e30e63fec7f5d7bb0b919.txt (13 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: images-2022-07-04T013450_jpg.rf.b41aaf504fb36c6098bae89a4dc2f173.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: Nein5887_jpg.rf.260b339dcb2c4ba773b2bc1b47effe41.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-42-07_e2bb7a0d_jpg.rf.ca2ce6d1d5d6f97b8325dbeb08497b6a.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 20220927_195254_jpg.rf.aed13147e830e694bca14d48946e187d.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: image_167_jpg.rf.81eb441556ad6821c32c7c6909c0e79a.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_40_jpeg_jpg.rf.97fdb7967a74dd1c869003ccdd1d5991.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: images-2022-07-04T013646-1-_jpg.rf.2253b3a9371358b49da6632fdc2fa6bc.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_26_jpeg_jpg.rf.3896c26882f1097c2f3185c047102328.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe_0364_jpg.rf.d68e5cff714aae3c69bbf3f4846973a8.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 20220621_132901_jpg.rf.794959fd1913064acbc8927620fe47c4.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: images-2022-07-04T011657_jpg.rf.bdc5c0a3fff33b56bd94852bd9a5fee4.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: KakaoTalk_20221018_001425789_06_jpg.rf.efe26050a7b06146e7f0822a2a03d61a.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: r13_jpg.rf.7b86fae426a1c890831a0dace3c97e57.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: Aitin1788_jpg.rf.2dfc09b94c76b589705ccd4aa4fd75be.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: images-29-_jpg.rf.f754bcf21fba2d849eee85298864f37c.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: gettyimages-665249214-612x612_jpg.rf.2c01da77af0d7adc1a1a4d8514c60da5.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_3_jpeg_jpg.rf.c2269d1d5b2aa2b70874fdec33766ea2.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_54_jpeg_jpg.rf.17944f8a60aef6c99a9d2265a2cd84eb.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_17_jpeg_jpg.rf.8ca3fb23ded12deb711e600f72a53dc1.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_33_jpeg_jpg.rf.d87d6e6f8074d4ddca360c2a76822892.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: construction-worker1_grande_jpg.rf.fb3ad23d71a68ebdc91612a1b370a833.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_28_jpeg_jpg.rf.d450aa513c3f22a51e6fed86ab5da144.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-42-16_b1f66ec4_jpg.rf.22fcdf3c4728707ceabb0ac15c9044ae.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_52_jpeg_jpg.rf.69ee4eda64283dc3b8f0724e6fcb4fde.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 20220721_124131_jpg.rf.7d652716261f31a4b5989cfe372bd858.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 107IMG__jpg.rf.178a73df151b9148139173922918ff6c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_82406d43_jpg.rf.a9e75b73527f6787f26462d883114a88.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: building-workers_42_jpeg_jpg.rf.593d116df865785e217f56e26566b92b.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe_0873_jpg.rf.a74880517b53097a1168085b1feebdb6.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe-workers_59_jpeg_jpg.rf.ac94e3c7bd13c2490a7a2609ee9d01b8.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-34-31_24d11c8b_jpg.rf.0f55791a7924e732c2de41a55c52d8e5.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-40-45_6cf5a940_jpg.rf.3bfdbfe05c44069a916bf30d8d61d9b1.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 9417812-serious-male-construction-worker-in-safety-vest-and-hard-hat_jpg.rf.1dbb968ecc7b374caf38c3a309a67591.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: best-leather-work-gloves_jpg.rf.b6ecdd88b39c52b38e884d2f6b9fc829.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: construction-crack-146741_jpg.rf.cfcd433845913de7a72a68863197e8b7.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: images-2022-07-04T013650_jpg.rf.0baf90bd92330b6489dc28d0ebc38b3a.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: ppe_1200_jpg.rf.d9c55a6dda412e4484be047611ef34f4.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: 00148_jpg.rf.8de66875b7d5d7c59a7bd28c8d2f5ef8.txt (8 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_61_jpeg_jpg.rf.0b5cf2a0620eef3174df7ed04695f3c9.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test
# ✅ Successfully transformed all labels from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/test/labels to /home/emma/facultad/pps/datasets/ppe-detection-yolov8-dataset/test/labels
# Empty files: ['images-2022-07-04T013450_jpg.rf.b41aaf504fb36c6098bae89a4dc2f173', 'Nein5887_jpg.rf.260b339dcb2c4ba773b2bc1b47effe41', 'images-2022-07-04T013646-1-_jpg.rf.2253b3a9371358b49da6632fdc2fa6bc', 'images-29-_jpg.rf.f754bcf21fba2d849eee85298864f37c', 'ppe-workers_59_jpeg_jpg.rf.ac94e3c7bd13c2490a7a2609ee9d01b8', 'images-2022-07-04T013650_jpg.rf.0baf90bd92330b6489dc28d0ebc38b3a']
# 🗑️  Removed empty image: images-2022-07-04T013450_jpg.rf.b41aaf504fb36c6098bae89a4dc2f173.jpg
# 🗑️  Removed empty label: images-2022-07-04T013450_jpg.rf.b41aaf504fb36c6098bae89a4dc2f173.txt
# 🗑️  Removed empty image: Nein5887_jpg.rf.260b339dcb2c4ba773b2bc1b47effe41.jpg
# 🗑️  Removed empty label: Nein5887_jpg.rf.260b339dcb2c4ba773b2bc1b47effe41.txt
# 🗑️  Removed empty image: images-2022-07-04T013646-1-_jpg.rf.2253b3a9371358b49da6632fdc2fa6bc.jpg
# 🗑️  Removed empty label: images-2022-07-04T013646-1-_jpg.rf.2253b3a9371358b49da6632fdc2fa6bc.txt
# 🗑️  Removed empty image: images-29-_jpg.rf.f754bcf21fba2d849eee85298864f37c.jpg
# 🗑️  Removed empty label: images-29-_jpg.rf.f754bcf21fba2d849eee85298864f37c.txt
# 🗑️  Removed empty image: ppe-workers_59_jpeg_jpg.rf.ac94e3c7bd13c2490a7a2609ee9d01b8.jpg
# 🗑️  Removed empty label: ppe-workers_59_jpeg_jpg.rf.ac94e3c7bd13c2490a7a2609ee9d01b8.txt
# 🗑️  Removed empty image: images-2022-07-04T013650_jpg.rf.0baf90bd92330b6489dc28d0ebc38b3a.jpg
# 🗑️  Removed empty label: images-2022-07-04T013650_jpg.rf.0baf90bd92330b6489dc28d0ebc38b3a.txt
# ✅ Removed 6 images and 6 labels with no useful content
# 🔄 Processing 984 images...
# ✅ Successfully processed 984/984 images to 640x640
# ✅ Transformed: images_jpeg_jpg.rf.4c4a83b9b5031ed027d2039dd84a792e.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 2021-11-16-1637029208390_jpg.rf.27bd1fb89fb840f5bc54700d47bfd954.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00381_jpg.rf.b87248a658da67a136b8a190f1af5a70.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_49_jpeg_jpg.rf.f14c2d89eda8d07bf715d6d15cff8cf3.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images237_jpg.rf.ba52776626dc26ebd8a540ec6ab945a2.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0925_jpg.rf.7d5095a83eb45bb61ac5167558ba2c16.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Tan0613613_jpg.rf.2b687e5d0aba8ab25c61d62bfccb0df9.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013721_jpg.rf.c06c4c4b7e7fa4ecaa8f6f3e4c72c34e.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013721_jpg.rf.d81a9198791402eed8acd04b5a112fa3.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013051_jpg.rf.4a7d06eb48bab1b0bf87aad54820c732.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Nein4145_jpg.rf.846fd0f937e463c9c3c87fb8ee7e292b.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00464_jpg.rf.1ba1657a2719551417c912a2b5e0b0ff.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-36-07_fd481348_jpg.rf.87268fcd023cf7bde9a89fd86323c774.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 2021-11-16-1637029208390_jpg.rf.4c39c348adfdf858bd2ef060161a4e4c.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 51_JPG_jpg.rf.ee5273720dfb891440ca3d2c1c110f9c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 108IMG__jpg.rf.fbeaed78e8cf1bf4da7c73c9dce4a6fe.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_161_jpg.rf.c9afce9e5515f7079a9a50f743bb16a4.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Photin0014_jpg.rf.c686ead48c9df1031c62b72527d7f8f4.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0185_jpg.rf.e845be44e8420d4fe1998077813356e4.txt (7 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00020_jpg.rf.d54bab6f39207a2b1ca604d617ca3553.txt (11 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: D3O-Impact-Additives-1000x641_jpg.rf.185ffe1b99c55edb2598247789c59880.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_165_jpg.rf.02bbee7a74f2c477bc6902a0e5ab09d6.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0352_jpg.rf.c02787ea1df33e7aad6aa8ca80fa66b8.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Photin0518_jpg.rf.e86bebdb46338cbb5b78658efb629997.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00236_jpg.rf.a0dafae8cec88b0992dc2ec7d9e0b334.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: download-27-_jpg.rf.49b628dbb0c956f4919f67187ce1e41c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: sic2817_jpg.rf.20ebba63f8012c8d40c28eb46b24e5d2.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 20220721_162157_jpg.rf.5241d910e48f10fad2a9c8b5069331dc.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_1207_jpg.rf.15b5f714ce354f59ef783c728eb65cf4.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-43_a304e5dd_jpg.rf.38a2a1ba50660825eef958f8f67b4bb9.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0518_jpg.rf.ac3c0acaf75607f3d7a4b010ef0d23c7.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: sic2817_jpg.rf.df96360e1c2a65c854c416ed1c213c50.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0771_jpg.rf.76b43df963720457429509f45bbe8614.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_165_jpg.rf.af7e53b411f280f0903c91a3af100f16.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 13IMG__jpg.rf.a7f3e4db7b2d67a3bea50745c1bb8a9c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_1ef65997_jpg.rf.cd067bad5428652495929ae584b3e9bb.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0311_jpg.rf.5c9f3bc4ee99c3cafe6776ce6a8f720e.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: li-lin-rZcC9J5ZT6I-unsplash_jpg.rf.a06ed5a8c85956efe1af49e08ed1565a.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-43_a304e5dd_jpg.rf.69da4e505355573fbd436137f795acb7.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0307_jpg.rf.c872f28d1f6960674f7cb530a5461e2e.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-47_4943e929_jpg.rf.afce7fbf377a57e78609742c278d61ee.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013101_jpg.rf.9b7fc256c957cb953ce759b804df926e.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00212_jpg.rf.246a1563863edc7af9f0ad701b183e37.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_63_jpeg_jpg.rf.b90c1754f9e3fa87cd5c26520c9c691d.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 16IMG__jpg.rf.9f0a676f1a0bcc6084c79bc05cb77aca.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-42-14_fce974d4_jpg.rf.548f42e0ce3cc222a80573dc21fa21cd.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013805_jpg.rf.3804c6363483ba9230f13dbcdc271b11.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_25_jpeg_jpg.rf.9a34529a23131a25c1e928370e0362f7.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_22_jpeg_jpg.rf.58ef6f03a05b03e8eac0406fb9bed2fc.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_159_jpg.rf.330f1f5d5bb8e04ef17118c73f11ba17.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_29_jpeg_jpg.rf.6bc76199259270571b3eaf74a10433b0.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-47_4943e929_jpg.rf.b37b6e1a9b29a5cda3b5727994a545ab.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00037_jpg.rf.0b3bba3e6fd8ab65767183915be48720.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_52_jpeg_jpg.rf.fadaa4fbd140bb6c55218f8922701251.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Photin0518_jpg.rf.c3324f58154b805b5745c6a43da2c9b6.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-45-32_3c6585a3_jpg.rf.66beffe73bebd99fe2dbd4d1101d564a.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0674_jpg.rf.5645f32978104da845f48dffb622b66f.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-42-16_ee180b2b_jpg.rf.5d04383f4fd83a3cf0c5f859f4b3e04f.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00037_jpg.rf.13d1e4e0e1978f1d475548615ccad143.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_52_jpeg_jpg.rf.598d6bc2d4042744981e22637c6a1545.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_1270_jpg.rf.847f6f71e06a8ac6d031ba48f1e70236.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00014_jpg.rf.8283b7395daefa0cf9869b1ee82adb69.txt (8 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013524_jpg.rf.7b9f5b5169a9e7601d86c3b7bab35814.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_22_jpeg_jpg.rf.8738402707ed074a95934462687e1b03.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 113IMG__jpg.rf.e8043b9ac7840770119f64b3faffbe86.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00016_jpg.rf.b1baa1e0772236c4026cb91bfefa3de5.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 13IMG__jpg.rf.f5849b45b5e9902fcf8dea839b3e3c63.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_21_png_jpg.rf.5758e1f24bdd4a402eda2bac40ca43c9.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_6_jpeg_jpg.rf.e5b6e066a7951f1206b1a44745f7cbb8.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00016_jpg.rf.b41c697dc5aa857f91e81e2042adc810.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T012932_jpg.rf.1f157649a4483ead0cfe4494d7d28d14.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013853_jpg.rf.19d4bcda5e0d7c7702efdd867836fd58.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 01459_jpg.rf.3dfb1f8fabe5f8eee5f31bf68c078151.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013616_jpg.rf.56598df82a07700f16a4eb62e248c1dc.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 2IMG__jpg.rf.f0b9a4e825b214494026928d189f38cf.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Photin0518_jpg.rf.2c0cc934086b8a5d7e8874f14eee882e.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_173a0f4f_jpg.rf.0d1bdade31e6341912d198b1ea8c212f.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 20220621_132920_jpg.rf.e4388e162b9368cb925ed925630337c7.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_165_jpg.rf.e2d1fb3f0bf831f0b80f55c50d417c4d.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 48-22-8752_C_600px-800x533_jpg.rf.8ab863ddfa2569a65019bcff4bd870e3.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: r120_jpg.rf.eeba389f81af18bd9cc25d6abf116049.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 1000_F_302135838_lIwqZCSBaXWzuryFuJD0noqYepnf5ljg_jpg.rf.01fbf3994208cbfa9a7dbe620ccab61a.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: r120_jpg.rf.a019a17c9c72b82936c68fe47a78d0e2.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 20220621_132920_jpg.rf.c904a26cb34c66c49bd3f73ce31d3dbb.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-56-_jpg.rf.654a74a72cef000cb92a3a5125c09466.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0895_jpg.rf.56ba7071af071249a6c1eae8d36e09a4.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_157_jpg.rf.1c4bb0e04cb353f75514bb3502676825.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00004_jpg.rf.f6b7d35369fcbbcd9c30996027e655f6.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 10_JPG_jpg.rf.568eb74ebfde280cb8a1e350368452ae.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 01459_jpg.rf.285c6190cb313355aff0f4500a51dc9a.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Schnittschutzhandschuhe_Header_jpg.rf.3a0d742c8b62a9495f03150a4eb6a7e8.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0146_jpg.rf.029bca5ff08029e2b5ed250e6adaa995.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-38-58_f088e19c_jpg.rf.83176699e642ce518c252ce3ac9c36bf.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_7_jpeg_jpg.rf.bbf84d424e6989c7edac2076debfcf69.txt (7 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: D3O-Impact-Additives-1000x641_jpg.rf.bc4f9417eadadf712844b4bf7077893e.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_36_jpeg_jpg.rf.dcd11f7ea8d462c7b0b83052557bb80c.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_39_png_jpg.rf.8ff220f52d1f7c3cc4408bacc9138252.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-34-35_e18f05f9_jpg.rf.eaacaf38a2810e1254c75bcb3217a0f8.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013745_jpg.rf.b5a94979e06acc2d73efd64dbd89e8e1.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 46_JPG_jpg.rf.fccf8ffaf0f53e344a44dd3416288c67.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images85_jpg.rf.7bfff30d2b1c27ce8c7d524b1a43055a.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: warehouse-worker_jpg.rf.af3c8ffb3b7f58e048b85181112cd2fe.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-38-55_3ebab3a6_jpg.rf.532437a8b830a277530cd6209bf8f9ee.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_161_jpg.rf.7252ff12bb809388e09546e01f79f9e5.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0140_jpg.rf.78067ff7d69166c892f17d7f70970c0d.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013828_jpg.rf.02dd0e42af5e4500c2035855fbf323a5.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images49_jpg.rf.29fa50477a897ed8856a9f66e98b0a1e.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_22_jpeg_jpg.rf.70344a4eb609ad503a55a33e134a0cd8.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0648_jpg.rf.85c24dc77f41dfc28c71143fffe3cb94.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_173a0f4f_jpg.rf.65609e5d8142b5d6036ca57897ab8a5c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: KakaoTalk_20221018_001219713_18_jpg.rf.c31eebe28d27aac2bae4115df619c49c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_63_jpeg_jpg.rf.fee0b41dc620fb75e1b6b296b85f1d22.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013738_jpg.rf.41a8db81fbf05cdfe88a6ca06e345ef5.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: download-27-_jpg.rf.d7e7bfc960436233ef5aeb492af91ff4.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: gettyimages-650169013-612x612_jpg.rf.9dff2536460fd82227768b5dee4407dd.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T012922_jpg.rf.b24563d6551a9687b9f11d4dd14acb90.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013832_jpg.rf.2ff67c498b1803620ef6b7293d35e337.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Aitin1170_jpg.rf.07111ce35216e913f52cd135c42b2b07.txt (7 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Bailey_jpg.rf.6998c0b0ce0b6f18f57d3de24dd275bf.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 28IMG__jpg.rf.b8294774808394f68c4aca4635903680.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 25IMG__jpg.rf.f833086ce1c0172e40c068ed3224aaf1.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0961_jpg.rf.a074a264adb4cbc39e191bed001a740d.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_51_jpeg_jpg.rf.1746e0463a0067952150bb0205f654b5.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: download-1-_jpeg_jpg.rf.bb0d98a0c2ef238397c192674d15d4f4.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Nein5542_jpg.rf.46f79c7bb0678c56ef1105714cb01fb4.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00056_jpg.rf.5836a73d88920aa5785a89c5a49146b9.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-45-30_b7606c75_jpg.rf.aff4b4c59fc4627a92cdacb3b78c3566.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 15IMG__jpg.rf.ebbaded3740cf2e9217d12d775e26f95.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_52_jpeg_jpg.rf.050b3b7b7a95cbc52dc40deaa6f36f19.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ezgif-frame-141_jpg.rf.f8ff820844444a40a59468c8666ca456.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-36-06_03acb6ac_jpg.rf.1b832ae0ac9c184b3b0c4e149c40c8f6.txt (7 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_169_jpg.rf.923218199ce4e6ae4acf854353462f45.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00014_jpg.rf.19d803f27bff4cf5084b84b558c8e7e6.txt (8 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_21_png_jpg.rf.75aa25b583476b603a3f5335ed7722e9.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013634_jpg.rf.a6a294c38d27c4592b80dc8bd9582275.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_35_jpeg_jpg.rf.28cc4bcb5ea7f0289f5a3e5cdfd97e03.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: li-lin-rZcC9J5ZT6I-unsplash_jpg.rf.f433895799b6e1130a4523ddf5bc0ef3.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_19_jpeg_jpg.rf.810f6cabd40f0f08691f497a87d922a5.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00572_jpg.rf.0e169570ab992b869dab15745a67b609.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_53_jpeg_jpg.rf.270d15579166e96f35405e5e1f02c08d.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013630_jpg.rf.769b09711b85be01311ce459005b08d6.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013441_jpg.rf.24cb229ffa6fc6b97ce61b565d5d8b1e.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images49_jpg.rf.f1e7e0746154aa9e419a390d943d03bb.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00052_jpg.rf.220186dbfe18291db2ab753325870b5a.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_25_jpeg_jpg.rf.7a883f2d53d4d0be56e06a34771a9a40.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013853_jpg.rf.de9b92579f478af0e8ed5ca6f6f6546d.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_21_jpeg_jpg.rf.f29954dd2ddeff78b43d4277cbcf7d99.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T011552_jpg.rf.f9284812701dc0d40098dd1456185b29.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: r116_jpg.rf.067865cb62bb1a2871bf4d273af139da.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-36-06_f1d5a54c_jpg.rf.14e03f2063188793f1e98b81c6d28829.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Nein4497_jpg.rf.a22ea35bd37864d373a27b4c147775ad.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_44_jpeg_jpg.rf.84316d33e7c2e0b1d2727dd7f57292d6.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0140_jpg.rf.b0483d9da88896907c943a7e11ff63cd.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00566_jpg.rf.4c6e909dd1ca1c2a6d326796d2da8c0f.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: gloves-_0007_Leather-Gloves_jpg.rf.dcdf052af44060ece00c739d9399c7c4.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 1_1125x_jpg.rf.db2486b11444bdb151838eabfaf2d949.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-31-_jpg.rf.58ebe78d2ed694954cdd1c29a166fee9.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 15IMG__jpg.rf.819ca014a17278d3ea5b4cff4511ad2a.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_167_jpg.rf.db55d43f15554c320339202b2444094e.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-38-55_3ebab3a6_jpg.rf.4437e0cab255bec8f98844de431b9f9f.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_169_jpg.rf.48a23de3fec567024ca74f6246f661e8.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: KakaoTalk_20221018_001219713_16_jpg.rf.d531358a850d3a80158de19e589a7c87.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Artboard_1_59527ea5-9b68-4c50-9fdb-637471a23f63_jpg.rf.e30d45b414d075aa9a716959e781535c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013836_jpg.rf.91fe4737ea13da1027f003c148b7157a.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-38-57_95c611e8_jpg.rf.7e82684dfed59dffd541a7f48341a544.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0974_jpg.rf.f2733e94e72f91bf8d1ec7a52bb21b63.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013630_jpg.rf.30b192c0c7ae8f2f1e6f689d7edc857d.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 1000_F_302135838_lIwqZCSBaXWzuryFuJD0noqYepnf5ljg_jpg.rf.4c805fb43ca3ca6311d00a360858216d.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0153_jpg.rf.e9cd703df392279005f07502fe3a0aef.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0137_jpg.rf.0ebc82d81f95637e79db631c247900a0.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: r100_jpg.rf.5fefbff734d9ed6fadbb66e49fdea17b.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0895_jpg.rf.4682345a519d359213a0deba368526c0.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ezgif-frame-141_jpg.rf.4e646cb61219af3c2a1f5b09ef6f91b3.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_48345555_jpg.rf.29ec4c253905f4fff33d533e9426e49b.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_7_png_jpg.rf.701b73e7df93fade90c7b9fb4a276f9f.txt (6 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_8b36c6ab_jpg.rf.24f3f04acc4b08470f98fe047073a924.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013925_jpg.rf.7748b07484b4f92ed09c583657886300.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013920_jpg.rf.1847e93c2018df51bb1cb09aa9897da0.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: KakaoTalk_20221018_001219713_16_jpg.rf.6776e6cf3e75f7b954499f184635c4fb.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-68-_jpg.rf.17310b42547ce8ce1c0ce12a9494db2b.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_49_jpeg_jpg.rf.accb04ca6ab6a2e0779f807ca68a7ffd.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_41_jpeg_jpg.rf.deff7437fc27a65a226cf814013cee94.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013839_jpg.rf.c6d93bc3b251e8c19bc5a11fd4086a81.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0518_jpg.rf.d531220b29eae3e8e49debdc59cdbe5c.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Photin0730_jpg.rf.f29eb2963d22a5e92bfbf2f1e3aa2b2d.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_40_jpeg_jpg.rf.3aa5f6c09d98d6fc76a45fb0d8596825.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe_0546_jpg.rf.c67d7da40ad567247340b9fe95e8ac98.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013955_jpg.rf.524e12d76faaf61e577550bff96e4e84.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 9IMG__jpg.rf.ac82e4b48277325c8e12b77213a5bfa4.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 20220621_132924_jpg.rf.a75865c71f5965b938bf79822c9e05c7.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_38_jpeg_jpg.rf.f6110d1b9d80a2025e1c76d24ec5a9a3.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_46_jpeg_jpg.rf.46589c781bd1f1c5156ba20bdaed19ff.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 20220721_162848_jpg.rf.21e9f8d036fc2961013c34035668a8d3.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_44_jpeg_jpg.rf.f59e3ae6c0651b1544405ed372cb5f67.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 9IMG__jpg.rf.370e12434eee5028f0a6f4ea20e977ae.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-Workers-Wearing-Safety-Equipment_38_jpeg_jpg.rf.17cd1a08dffa87c2559daace48be5dbc.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-36-_jpg.rf.b26d09143a2cd09e2b9df6b6ab9fb55b.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 31IMG__jpg.rf.a376bcb7a78d32a5ada578cfa0b3c0c2.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_204_jpg.rf.73938d26c4116c13cc76e2e9affd9091.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 00695_jpg.rf.6692b782b378d13d632dbb19260b9561.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_165-1-_jpg.rf.d58cc33ffda2f5a462e054ef73e3391d.txt (3 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: building-workers_9_jpeg_jpg.rf.77895e865340f510ac0490f8503f9343.txt (5 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Aitin1315_jpg.rf.647a0a022536d7c9a9f6bd26d70b4fdd.txt (6 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: KakaoTalk_20221018_001219713_26_jpg.rf.c3e48313a3e678714d1c5c69f236705e.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Tan0710710_jpg.rf.f78ea2fbdb486cdde75461b5749e4e4b.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: Nein4145_jpg.rf.4a69ac122abde8dbc7c4be76827fbb1b.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-47_4943e929_jpg.rf.d42a1547617ef19debc74a9578c87479.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-27-saat-14-42-03_e110e4fc_jpg.rf.151ceb2cac26c649aca6c8920eeb5abc.txt (2 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013948_jpg.rf.9ed0b46dae86f986c952e049c147c75c.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: image_161_jpg.rf.f43ad6149f053b2f6a5887f24e0bd602.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-19-45_0ddeb6da_jpg.rf.39d997db482634ff89d7685c43fb4890.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: images-2022-07-04T013745_jpg.rf.7ba7c549ce47cbbc93379791b87c0152.txt (0 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 25IMG__jpg.rf.95829ab90485533b018c4d4349cd7481.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: WhatsApp-Gorsel-2024-04-30-saat-12-38-58_0ec7807c_jpg.rf.b618691dce7a185bfaba8dec4f42b148.txt (4 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: 2IMG__jpg.rf.68c40f7fa74a028bcf9ac472141f6d60.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ✅ Transformed: ppe-workers_6_jpeg_jpg.rf.4a57d44bd87dbcefd5a23c1a04714221.txt (1 lines kept) from /home/emma/Downloads/PPE_Detection_YOLOv8.v11-8-1-1-32-epoch.yolov11/train
# ...
# 🗑️  Removed empty label: WhatsApp-Gorsel-2024-04-27-saat-14-51-39_6b9231f4_jpg.rf.8b5734865f8a6753f94a454975aab3d8.txt
# 🗑️  Removed empty image: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.dc0f5de7ca27ed07068f7fd15b0ef3f4.jpg
# 🗑️  Removed empty label: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.dc0f5de7ca27ed07068f7fd15b0ef3f4.txt
# 🗑️  Removed empty image: images_jpeg_jpg.rf.71d73ae096f1bb397f9d09421dff3366.jpg
# 🗑️  Removed empty label: images_jpeg_jpg.rf.71d73ae096f1bb397f9d09421dff3366.txt
# 🗑️  Removed empty image: images-2022-07-04T013139_jpg.rf.36f8d60fa756cf68ed47f3bf1eab2593.jpg
# 🗑️  Removed empty label: images-2022-07-04T013139_jpg.rf.36f8d60fa756cf68ed47f3bf1eab2593.txt
# 🗑️  Removed empty image: images-2022-07-04T014014_jpg.rf.2a34387f673b9b2a9dc7a615014b8341.jpg
# 🗑️  Removed empty label: images-2022-07-04T014014_jpg.rf.2a34387f673b9b2a9dc7a615014b8341.txt
# 🗑️  Removed empty image: images-2022-07-04T013805_jpg.rf.c7363e6da14a21e37bf0be18a2ff17d1.jpg
# 🗑️  Removed empty label: images-2022-07-04T013805_jpg.rf.c7363e6da14a21e37bf0be18a2ff17d1.txt
# 🗑️  Removed empty image: Photin0730_jpg.rf.1974643fd069417e21c352fbe4ae6d46.jpg
# 🗑️  Removed empty label: Photin0730_jpg.rf.1974643fd069417e21c352fbe4ae6d46.txt
# 🗑️  Removed empty image: images-2022-07-04T013937_jpg.rf.031c7b9f56a816621bdc9e88293f19da.jpg
# 🗑️  Removed empty label: images-2022-07-04T013937_jpg.rf.031c7b9f56a816621bdc9e88293f19da.txt
# 🗑️  Removed empty image: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.58f7e9ab363a4c4a4e0088a4c63285ca.jpg
# 🗑️  Removed empty label: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.58f7e9ab363a4c4a4e0088a4c63285ca.txt
# 🗑️  Removed empty image: images-2022-07-04T014007_jpg.rf.98df6ca983906406f97b77bc7ccc854c.jpg
# 🗑️  Removed empty label: images-2022-07-04T014007_jpg.rf.98df6ca983906406f97b77bc7ccc854c.txt
# 🗑️  Removed empty image: images-2022-07-04T013931_jpg.rf.2323a65056a3dcf6ca66fb2713c3c8c3.jpg
# 🗑️  Removed empty label: images-2022-07-04T013931_jpg.rf.2323a65056a3dcf6ca66fb2713c3c8c3.txt
# 🗑️  Removed empty image: images-2022-07-04T013828_jpg.rf.5095b43210ad9761b433d2e831adccd6.jpg
# 🗑️  Removed empty label: images-2022-07-04T013828_jpg.rf.5095b43210ad9761b433d2e831adccd6.txt
# 🗑️  Removed empty image: images-2022-07-04T013151_jpg.rf.1ff4453cda2ed7890d51d02c00f3bf4c.jpg
# 🗑️  Removed empty label: images-2022-07-04T013151_jpg.rf.1ff4453cda2ed7890d51d02c00f3bf4c.txt
# 🗑️  Removed empty image: images-2022-07-04T013716_jpg.rf.bbdd43616157e0348a3abbe5a2a58a5e.jpg
# 🗑️  Removed empty label: images-2022-07-04T013716_jpg.rf.bbdd43616157e0348a3abbe5a2a58a5e.txt
# 🗑️  Removed empty image: download-31-_jpg.rf.2bf361e725b363acfe9f65a981739814.jpg
# 🗑️  Removed empty label: download-31-_jpg.rf.2bf361e725b363acfe9f65a981739814.txt
# 🗑️  Removed empty image: images-2022-07-04T013931_jpg.rf.bb90556a724dfd6839dfd67ed5f8f47b.jpg
# 🗑️  Removed empty label: images-2022-07-04T013931_jpg.rf.bb90556a724dfd6839dfd67ed5f8f47b.txt
# 🗑️  Removed empty image: WhatsApp-Gorsel-2024-04-27-saat-14-51-39_6b9231f4_jpg.rf.4b7c08daf965a1ad7a11b66deec4d4d9.jpg
# 🗑️  Removed empty label: WhatsApp-Gorsel-2024-04-27-saat-14-51-39_6b9231f4_jpg.rf.4b7c08daf965a1ad7a11b66deec4d4d9.txt
# 🗑️  Removed empty image: images-2022-07-04T013524_jpg.rf.b828d4bbe534dffe72423ad85f4ff8a1.jpg
# 🗑️  Removed empty label: images-2022-07-04T013524_jpg.rf.b828d4bbe534dffe72423ad85f4ff8a1.txt
# 🗑️  Removed empty image: images-2022-07-04T013738_jpg.rf.43a3ed7f468f27040176b4580cc008e1.jpg
# 🗑️  Removed empty label: images-2022-07-04T013738_jpg.rf.43a3ed7f468f27040176b4580cc008e1.txt
# 🗑️  Removed empty image: 20220721_162848_jpg.rf.67a14a0b508592b3e28eecd8de1dd652.jpg
# 🗑️  Removed empty label: 20220721_162848_jpg.rf.67a14a0b508592b3e28eecd8de1dd652.txt
# 🗑️  Removed empty image: Nein5542_jpg.rf.db7bcd4be699cc9a10cd3049f77bbc97.jpg
# 🗑️  Removed empty label: Nein5542_jpg.rf.db7bcd4be699cc9a10cd3049f77bbc97.txt
# 🗑️  Removed empty image: images-2022-07-04T013839_jpg.rf.493c83f544647dabfe14c3bdd50b7fe4.jpg
# 🗑️  Removed empty label: images-2022-07-04T013839_jpg.rf.493c83f544647dabfe14c3bdd50b7fe4.txt
# 🗑️  Removed empty image: images-2022-07-04T013856_jpg.rf.eba0158dd9571e15e7a96c69fef808c7.jpg
# 🗑️  Removed empty label: images-2022-07-04T013856_jpg.rf.eba0158dd9571e15e7a96c69fef808c7.txt
# 🗑️  Removed empty image: images-2022-07-04T013745_jpg.rf.ef72a69ebe168d183e14b059f7dd09b2.jpg
# 🗑️  Removed empty label: images-2022-07-04T013745_jpg.rf.ef72a69ebe168d183e14b059f7dd09b2.txt
# 🗑️  Removed empty image: images-2022-07-04T013937_jpg.rf.70a23a516b709f04750ece4e6c6a204a.jpg
# 🗑️  Removed empty label: images-2022-07-04T013937_jpg.rf.70a23a516b709f04750ece4e6c6a204a.txt
# 🗑️  Removed empty image: ezgif-frame-030_jpg.rf.ce5d4430857dd9f5ff0858bfab7b448d.jpg
# 🗑️  Removed empty label: ezgif-frame-030_jpg.rf.ce5d4430857dd9f5ff0858bfab7b448d.txt
# 🗑️  Removed empty image: images-2022-07-04T013907_jpg.rf.212ad5e46b090c2e77ef3c0c2837e158.jpg
# 🗑️  Removed empty label: images-2022-07-04T013907_jpg.rf.212ad5e46b090c2e77ef3c0c2837e158.txt
# 🗑️  Removed empty image: images-2022-07-04T013729_jpg.rf.4fd7369870c1613e89882bdbe6c23bf7.jpg
# 🗑️  Removed empty label: images-2022-07-04T013729_jpg.rf.4fd7369870c1613e89882bdbe6c23bf7.txt
# 🗑️  Removed empty image: Photin0314_jpg.rf.63623fb7077c49df92268015787e5b3c.jpg
# 🗑️  Removed empty label: Photin0314_jpg.rf.63623fb7077c49df92268015787e5b3c.txt
# 🗑️  Removed empty image: Driver-gloves-1_jpg.rf.0e217c566fa88d023ce7258628ed36b4.jpg
# 🗑️  Removed empty label: Driver-gloves-1_jpg.rf.0e217c566fa88d023ce7258628ed36b4.txt
# 🗑️  Removed empty image: ppe_0961_jpg.rf.dd1d451fb9f9912c3dfa7e606c06a854.jpg
# 🗑️  Removed empty label: ppe_0961_jpg.rf.dd1d451fb9f9912c3dfa7e606c06a854.txt
# 🗑️  Removed empty image: images-2022-07-04T013721_jpg.rf.a8f57a47b38e4fcd5ea74fd985983c10.jpg
# 🗑️  Removed empty label: images-2022-07-04T013721_jpg.rf.a8f57a47b38e4fcd5ea74fd985983c10.txt
# 🗑️  Removed empty image: images-2022-07-04T013724_jpg.rf.649ed8b54a5982392f11f8d84af49f65.jpg
# 🗑️  Removed empty label: images-2022-07-04T013724_jpg.rf.649ed8b54a5982392f11f8d84af49f65.txt
# 🗑️  Removed empty image: Photin0529_jpg.rf.4deca1d5dd5c82b7ae1fc279a3242848.jpg
# 🗑️  Removed empty label: Photin0529_jpg.rf.4deca1d5dd5c82b7ae1fc279a3242848.txt
# 🗑️  Removed empty image: images-68-_jpg.rf.31f2ad00782bd0d0a90b5ce6bfd81244.jpg
# 🗑️  Removed empty label: images-68-_jpg.rf.31f2ad00782bd0d0a90b5ce6bfd81244.txt
# 🗑️  Removed empty image: images-2022-07-04T013729_jpg.rf.3fc59bfae6785903e70af7d09602800b.jpg
# 🗑️  Removed empty label: images-2022-07-04T013729_jpg.rf.3fc59bfae6785903e70af7d09602800b.txt
# 🗑️  Removed empty image: Driver-gloves-1_jpg.rf.f10662bff3f67d3a9f41fc1116da4f56.jpg
# 🗑️  Removed empty label: Driver-gloves-1_jpg.rf.f10662bff3f67d3a9f41fc1116da4f56.txt
# 🗑️  Removed empty image: images-2022-07-04T013157_jpg.rf.4762f3791a5df255aaf27745c2bdc49e.jpg
# 🗑️  Removed empty label: images-2022-07-04T013157_jpg.rf.4762f3791a5df255aaf27745c2bdc49e.txt
# 🗑️  Removed empty image: ezgif-frame-030_jpg.rf.e32cd74610d61582be7fc2dae4ca5637.jpg
# 🗑️  Removed empty label: ezgif-frame-030_jpg.rf.e32cd74610d61582be7fc2dae4ca5637.txt
# 🗑️  Removed empty image: Photin0014_jpg.rf.772833c6bd876aeb6cb791b99eeab10c.jpg
# 🗑️  Removed empty label: Photin0014_jpg.rf.772833c6bd876aeb6cb791b99eeab10c.txt
# 🗑️  Removed empty image: ppe_0961_jpg.rf.9b142a30fa77d464b350ba6ad2a5ebed.jpg
# 🗑️  Removed empty label: ppe_0961_jpg.rf.9b142a30fa77d464b350ba6ad2a5ebed.txt
# 🗑️  Removed empty image: Photin0973_jpg.rf.26a574aa092cd732decb82a23f24d69f.jpg
# 🗑️  Removed empty label: Photin0973_jpg.rf.26a574aa092cd732decb82a23f24d69f.txt
# 🗑️  Removed empty image: images-2022-07-04T013937_jpg.rf.247727ddb627f40b55d5e3c9494e4ded.jpg
# 🗑️  Removed empty label: images-2022-07-04T013937_jpg.rf.247727ddb627f40b55d5e3c9494e4ded.txt
# 🗑️  Removed empty image: images-2022-07-04T013856_jpg.rf.884696857c7dee372d1d271ef1331d73.jpg
# 🗑️  Removed empty label: images-2022-07-04T013856_jpg.rf.884696857c7dee372d1d271ef1331d73.txt
# 🗑️  Removed empty image: Photin0529_jpg.rf.29a4d7fd697d14ea352b9c63cdbef295.jpg
# 🗑️  Removed empty label: Photin0529_jpg.rf.29a4d7fd697d14ea352b9c63cdbef295.txt
# 🗑️  Removed empty image: images-34-_jpg.rf.77decdd1973ab8fccb803f9e38fe23de.jpg
# 🗑️  Removed empty label: images-34-_jpg.rf.77decdd1973ab8fccb803f9e38fe23de.txt
# 🗑️  Removed empty image: 20220721_162157_jpg.rf.ce009fe73016bb35cdad20263d94d199.jpg
# 🗑️  Removed empty label: 20220721_162157_jpg.rf.ce009fe73016bb35cdad20263d94d199.txt
# 🗑️  Removed empty image: Photin0314_jpg.rf.b14341c98054d0f68067963d9a81653b.jpg
# 🗑️  Removed empty label: Photin0314_jpg.rf.b14341c98054d0f68067963d9a81653b.txt
# 🗑️  Removed empty image: Photin0529_jpg.rf.4445f4eb675b1fa9d457664a417398e3.jpg
# 🗑️  Removed empty label: Photin0529_jpg.rf.4445f4eb675b1fa9d457664a417398e3.txt
# 🗑️  Removed empty image: images-2022-07-04T013444_jpg.rf.2e2647e66e9b5e743b8d5d494b7a210f.jpg
# 🗑️  Removed empty label: images-2022-07-04T013444_jpg.rf.2e2647e66e9b5e743b8d5d494b7a210f.txt
# 🗑️  Removed empty image: 20220721_162553_jpg.rf.308a7dfb9beef0e41db576c1d324bcdd.jpg
# 🗑️  Removed empty label: 20220721_162553_jpg.rf.308a7dfb9beef0e41db576c1d324bcdd.txt
# 🗑️  Removed empty image: images-2022-07-04T013839_jpg.rf.e93963a036098f52969a236a6b90345c.jpg
# 🗑️  Removed empty label: images-2022-07-04T013839_jpg.rf.e93963a036098f52969a236a6b90345c.txt
# 🗑️  Removed empty image: 20220721_162553_jpg.rf.29baf52eb9131a4dad13ba5a25aa152f.jpg
# 🗑️  Removed empty label: 20220721_162553_jpg.rf.29baf52eb9131a4dad13ba5a25aa152f.txt
# 🗑️  Removed empty image: images-2022-07-04T013634_jpg.rf.5bae83df70ef4de449ce4592ef3d83aa.jpg
# 🗑️  Removed empty label: images-2022-07-04T013634_jpg.rf.5bae83df70ef4de449ce4592ef3d83aa.txt
# 🗑️  Removed empty image: images-2022-07-04T013700_jpg.rf.9e90338d4da7a842b6d7cd2af0fb0578.jpg
# 🗑️  Removed empty label: images-2022-07-04T013700_jpg.rf.9e90338d4da7a842b6d7cd2af0fb0578.txt
# 🗑️  Removed empty image: 20220721_162553_jpg.rf.cb0d0f0b4514fcd2cb3b300bb4dc5651.jpg
# 🗑️  Removed empty label: 20220721_162553_jpg.rf.cb0d0f0b4514fcd2cb3b300bb4dc5651.txt
# 🗑️  Removed empty image: 20220721_162848_jpg.rf.bf9943cc522ca1c1e58b3f3bdbe3f3fa.jpg
# 🗑️  Removed empty label: 20220721_162848_jpg.rf.bf9943cc522ca1c1e58b3f3bdbe3f3fa.txt
# 🗑️  Removed empty image: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.ea611a3b6ba673e61376f99aac8d9eed.jpg
# 🗑️  Removed empty label: WhatsApp-Gorsel-2024-04-27-saat-14-45-43_3da0697a_jpg.rf.ea611a3b6ba673e61376f99aac8d9eed.txt
# 🗑️  Removed empty image: images-2022-07-04T013716_jpg.rf.e5ddb49479e252a001ccbb949e5656f2.jpg
# 🗑️  Removed empty label: images-2022-07-04T013716_jpg.rf.e5ddb49479e252a001ccbb949e5656f2.txt
# 🗑️  Removed empty image: images-2022-07-04T013805_jpg.rf.9544632fd1ed7d476bfb8f51cec1ccea.jpg
# 🗑️  Removed empty label: images-2022-07-04T013805_jpg.rf.9544632fd1ed7d476bfb8f51cec1ccea.txt
# 🗑️  Removed empty image: images-2022-07-04T013157_jpg.rf.60d0bd74ddb01cffefe92f79abea0e75.jpg
# 🗑️  Removed empty label: images-2022-07-04T013157_jpg.rf.60d0bd74ddb01cffefe92f79abea0e75.txt
# 🗑️  Removed empty image: images-2022-07-04T013139_jpg.rf.e340d01317cbff21041c71f5f3d46e49.jpg
# 🗑️  Removed empty label: images-2022-07-04T013139_jpg.rf.e340d01317cbff21041c71f5f3d46e49.txt
# 🗑️  Removed empty image: images-2022-07-04T013700_jpg.rf.11be2ba776d90671850204c05c251003.jpg
# 🗑️  Removed empty label: images-2022-07-04T013700_jpg.rf.11be2ba776d90671850204c05c251003.txt
# 🗑️  Removed empty image: images-2022-07-04T013641_jpg.rf.af20203f0250fffc212b13660d7f0556.jpg
# 🗑️  Removed empty label: images-2022-07-04T013641_jpg.rf.af20203f0250fffc212b13660d7f0556.txt
# 🗑️  Removed empty image: images-2022-07-04T013151_jpg.rf.320c418ce09f7e353a138dfe518d5a8c.jpg
# 🗑️  Removed empty label: images-2022-07-04T013151_jpg.rf.320c418ce09f7e353a138dfe518d5a8c.txt
# 🗑️  Removed empty image: images-2022-07-04T013634_jpg.rf.fb7d48aacc44ef21406ff5a5c6e4f606.jpg
# 🗑️  Removed empty label: images-2022-07-04T013634_jpg.rf.fb7d48aacc44ef21406ff5a5c6e4f606.txt
# 🗑️  Removed empty image: Driver-gloves-1_jpg.rf.4149c3959a6ba63e43f0d07368976297.jpg
# 🗑️  Removed empty label: Driver-gloves-1_jpg.rf.4149c3959a6ba63e43f0d07368976297.txt
# 🗑️  Removed empty image: images-2022-07-04T013920_jpg.rf.f82d9029f4eeb270780c1d449b2bae59.jpg
# 🗑️  Removed empty label: images-2022-07-04T013920_jpg.rf.f82d9029f4eeb270780c1d449b2bae59.txt
# 🗑️  Removed empty image: images-2022-07-04T013517_jpg.rf.8c199fd3ff1eba4a7510db26e331db3e.jpg
# 🗑️  Removed empty label: images-2022-07-04T013517_jpg.rf.8c199fd3ff1eba4a7510db26e331db3e.txt
# 🗑️  Removed empty image: images-2022-07-04T013653_jpg.rf.2d262ab2dcbabe02e605a4fa1a1937a5.jpg
# 🗑️  Removed empty label: images-2022-07-04T013653_jpg.rf.2d262ab2dcbabe02e605a4fa1a1937a5.txt
# 🗑️  Removed empty image: Nein4497_jpg.rf.2858d42a59f9063419b15bfe7546d89c.jpg
# 🗑️  Removed empty label: Nein4497_jpg.rf.2858d42a59f9063419b15bfe7546d89c.txt
# 🗑️  Removed empty image: Nein5387_jpg.rf.27b6af93d2b75e7bb847bcb51ebaef43.jpg
# 🗑️  Removed empty label: Nein5387_jpg.rf.27b6af93d2b75e7bb847bcb51ebaef43.txt
# 🗑️  Removed empty image: Photin0014_jpg.rf.ab691a7f451365e5b3bf92cad0a58db4.jpg
# 🗑️  Removed empty label: Photin0014_jpg.rf.ab691a7f451365e5b3bf92cad0a58db4.txt
# 🗑️  Removed empty image: building-Workers-Wearing-Safety-Equipment_29_jpeg_jpg.rf.e150dbe6f8f8ad2f3d522b0445044056.jpg
# 🗑️  Removed empty label: building-Workers-Wearing-Safety-Equipment_29_jpeg_jpg.rf.e150dbe6f8f8ad2f3d522b0445044056.txt
# 🗑️  Removed empty image: download-31-_jpg.rf.76d8cbd653f584c47f193a2899338b18.jpg
# 🗑️  Removed empty label: download-31-_jpg.rf.76d8cbd653f584c47f193a2899338b18.txt
# 🗑️  Removed empty image: images-2022-07-04T013524_jpg.rf.2e82cf3059b3b08810d3753b119b9d21.jpg
# 🗑️  Removed empty label: images-2022-07-04T013524_jpg.rf.2e82cf3059b3b08810d3753b119b9d21.txt
# 🗑️  Removed empty image: Schnittschutzhandschuhe_Header_jpg.rf.529180882c06d72661707ef9ae54fec0.jpg
# 🗑️  Removed empty label: Schnittschutzhandschuhe_Header_jpg.rf.529180882c06d72661707ef9ae54fec0.txt
# 🗑️  Removed empty image: images-2022-07-04T013836_jpg.rf.5abfb7069e721c44b004830e234abec3.jpg
# 🗑️  Removed empty label: images-2022-07-04T013836_jpg.rf.5abfb7069e721c44b004830e234abec3.txt
# 🗑️  Removed empty image: images-2022-07-04T013616_jpg.rf.232dbfb2d04efed60e461926f649197c.jpg
# 🗑️  Removed empty label: images-2022-07-04T013616_jpg.rf.232dbfb2d04efed60e461926f649197c.txt
# 🗑️  Removed empty image: images-2022-07-04T013139_jpg.rf.f697aa888d309e3c7dfb4a6a6f2db21a.jpg
# 🗑️  Removed empty label: images-2022-07-04T013139_jpg.rf.f697aa888d309e3c7dfb4a6a6f2db21a.txt
# 🗑️  Removed empty image: images-68-_jpg.rf.36dbe841c50f1b35322209bd9df34150.jpg
# 🗑️  Removed empty label: images-68-_jpg.rf.36dbe841c50f1b35322209bd9df34150.txt
# 🗑️  Removed empty image: Photin0730_jpg.rf.a2580fb5dcc131ec16444562b4be7c85.jpg
# 🗑️  Removed empty label: Photin0730_jpg.rf.a2580fb5dcc131ec16444562b4be7c85.txt
# 🗑️  Removed empty image: Photin0973_jpg.rf.b3b694b4c45bdf733e88090292119a6f.jpg
# 🗑️  Removed empty label: Photin0973_jpg.rf.b3b694b4c45bdf733e88090292119a6f.txt
# 🗑️  Removed empty image: images-2022-07-04T013856_jpg.rf.76156da76c2874e258a1a0ae58975f8e.jpg
# 🗑️  Removed empty label: images-2022-07-04T013856_jpg.rf.76156da76c2874e258a1a0ae58975f8e.txt
# 🗑️  Removed empty image: images-2022-07-04T013955_jpg.rf.4176d0da43849bc760b0501c0a134cc0.jpg
# 🗑️  Removed empty label: images-2022-07-04T013955_jpg.rf.4176d0da43849bc760b0501c0a134cc0.txt
# 🗑️  Removed empty image: images-2022-07-04T014035_jpg.rf.abcc45e523f802c59ed59f286af13714.jpg
# 🗑️  Removed empty label: images-2022-07-04T014035_jpg.rf.abcc45e523f802c59ed59f286af13714.txt
# 🗑️  Removed empty image: Photin0973_jpg.rf.be1c612b8a71aa1420ef73b26ec96a21.jpg
# 🗑️  Removed empty label: Photin0973_jpg.rf.be1c612b8a71aa1420ef73b26ec96a21.txt
# 🗑️  Removed empty image: Photin0314_jpg.rf.72733cf184be483d256ac95e5a176305.jpg
# 🗑️  Removed empty label: Photin0314_jpg.rf.72733cf184be483d256ac95e5a176305.txt
# ✅ Removed 183 images and 183 labels with no useful content
